# %% [markdown]
# # Experiencia SEDICI
#
# ## Detección automática de repeticiones parciales en repositorios digitales
#
# El repositorio del proyecto es [Github](https://github.com/germanchaca/OAI-PMH-ABSTRACTS_PARTIAL_REPETITIONS-).
#
#
# ### Alcance
# * Se extraerán los metadatos de un proveedor de datos OAI-PMH y cómo convertir los datos recuperados de Dublin Core en un pandas dataframe. Se podrá utilizar le código en cualquiera de los proveedores de metadatos listados en buscadores como [sherpa](https://v2.sherpa.ac.uk/view/repository_by_country/Argentina.html) o [roar](http://roar.eprints.org/).
#
# * Se llevará a cabo un análisis de datos básico en sus datos para averiguar si los datos están corruptos o sucios.
# * Finalmente, se bucará detectar repeticiones parciales en el texto del abstract o resumen de los registros publicados en el repositorio SEDICI. EL código puede ser utilizado para detectar repeticiones parciales entre los distintos repositorios ditigales que soporten la interoperabilidad con OAI-PMH.
#
#
# ### Preparación del entorno de trabajo
# El siguiente fragmento de código inicializa su entorno de tiempo de ejecución de Python para ejecutar todas las acciones posteriores.
#
# Si ha instalado todo correctamente con la ayuda de [Anaconda](https://www.continuum.io/downloads), los siguientes paquetes deben instalarse correctamente y ser importados sin problemas.

# %%
# !pip install jellyfish
# !pip install geojson
# !pip install geopy
# !pip install sickle
# !pip install googlemaps

# %% [markdown]
# ### Sickle - Librería para el manejo de OAI-PMH
#
# [Sickle](https://sickle.readthedocs.io/en/latest/) es una biblioteca de OAI-PMH escrita en Python. Ha sido diseñado para recuperar datos cómodamente de OAI interactúa a la manera Pythonic

# %% [markdown]
# #### Additional Configuration of This Notebook

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 40)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("notebook")

from bs4 import BeautifulSoup
from collections import OrderedDict # provides the ordered dictionary
import re # for regular expressions used below
import urllib # to read from URLs
import json
import networkx as nx # network analysis
from networkx.readwrite import json_graph
import itertools
import os.path
from datetime import datetime # for time measurement
import sys
import os
import pickle
import subprocess as subp
import gzip
import math
import codecs

from jellyfish import jaro_distance, jaro_winkler, hamming_distance, levenshtein_distance
import scipy.cluster.hierarchy as scipycluster
from sklearn.feature_extraction.text import TfidfVectorizer

from skimage import io, exposure
from scipy.spatial import distance
# import the k-means algorithm
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.metrics import pairwise_distances_argmin,pairwise_distances_argmin_min, pairwise_distances
from sklearn.metrics.pairwise import euclidean_distances

# OAI
from sickle import Sickle

allowDownloads=True # should be True if you run this for the first time
downloadDir="./tmp/"
allowExactStringMatching=True

def printLog(text):
    now=str(datetime.now())
    print("["+now+"]\t"+text)
    # forces to output the result of the print command immediately, see: http://stackoverflow.com/questions/230751/how-to-flush-output-of-python-print
    sys.stdout.flush()
    
def pickleCompress(fileName,pickledObject):
    printLog("Pickling to '%s'" %fileName)
    f = gzip.open(fileName,'wb')
    pickle.dump(pickledObject,f)
    f.close()
    printLog("Pickling done.")
    
def pickleDecompress(fileName):
    #restore the object
    printLog("Depickling from '%s'" %fileName)
    f = gzip.open(fileName,'rb')
    pickledObject = pickle.load(f)
    f.close()
    printLog("Depickling done.")
    return pickledObject

if not os.path.exists(downloadDir):
        os.makedirs(downloadDir)
if not os.path.exists("./picklez/"):
        os.makedirs("./picklez/")

# %% [markdown]
# ## Recolección de metadatos de un repositorio digital
#
# ### Conexión al repositorio proveedor OAI y descarga de registros de metadatos
#
# La siguiente celda se conecta al servidor OAI-PMH de Repositorio de la Universidad Nacional de La Plata - [SEDICI](http://sedici.unlp.edu.ar/).
#
# los registros se guardan localmente para trabajar con ellos más tarde. Por simplicidad, el ahorro se basa en el mecanismo de pickling de Python, su método de serialización de objetos incorporado. En un caso de uso productivo, es posible que alcance los límites del paquete pickle debido al tamaño del archivo resultante. Una alternativa viable es [HDF5](https://www.h5py.org/).

# %%
repository_address = 'http://sedici.unlp.edu.ar/oai/snrd'
allowDownloads = True
#repository_address = 'http://repositorio.filo.uba.ar/oai/request'

# %% [markdown]
# Se listan los conjuntos o sets de datos proporcionados por el proveedor de datos

# %%
sickle = Sickle(repository_address)
sets = sickle.ListSets()
print ("Conjuntos proporcionados por el proveedor de datos\n* * * * * * * * * * * * * * * * * * * * * ") 
for s in sets:
     print("'"+s.setName+"' accessible via: '"+s.setSpec+"'")
# Out:
# Conjuntos proporcionados por el proveedor de datos
# * * * * * * * * * * * * * * * * * * * * *
# 'Conjunto de recursos para Sistema Nacional de Repositorios Digitales, Argentina SNRD' accessible via: 'snrd'
# 'Unidades académicas' accessible via: 'com_10915_1'
# 'Facultad de Ingeniería' accessible via: 'com_10915_2'
# 'Facultad de Ciencias Veterinarias' accessible via: 'com_10915_5'
# 'Facultad de Ciencias Jurídicas y Sociales' accessible via: 'com_10915_7'
# 'Facultad de Ciencias Agrarias y Forestales' accessible via: 'com_10915_10'
# 'Facultad de Periodismo y Comunicación Social' accessible via: 'com_10915_12'
# 'Facultad de Ciencias Astronómicas y Geofísicas' accessible via: 'com_10915_15'
# 'Facultad de Trabajo Social' accessible via: 'com_10915_18'
# 'Facultad de Odontología' accessible via: 'com_10915_20'
# 'Facultad de Ciencias Exactas' accessible via: 'com_10915_22'
# 'Facultad de Arquitectura y Urbanismo' accessible via: 'com_10915_25'
# 'Facultad de Psicología' accessible via: 'com_10915_28'
# 'Facultad de Humanidades y Ciencias de la Educación' accessible via: 'com_10915_30'
# 'Facultad de Ciencias Económicas' accessible via: 'com_10915_33'
# 'Facultad de Informática' accessible via: 'com_10915_36'
# 'Facultad de Bellas Artes' accessible via: 'com_10915_38'
# 'Facultad de Ciencias Naturales y Museo' accessible via: 'com_10915_41'
# 'Facultad de Ciencias Médicas' accessible via: 'com_10915_44'
# 'Presidencia' accessible via: 'com_10915_47'
# 'Revistas' accessible via: 'com_10915_51'
# 'Revista Argentina de Antropología Biológica' accessible via: 'com_10915_52'
# 'Boletín de la Asociación Herpetológica Argentina [Publicación cerrada]' accessible via: 'com_10915_71'
# 'Cuadernos de Herpetología' accessible via: 'com_10915_83'
# 'Acta Farmacéutica Bonaerense [Publicación cerrada]' accessible via: 'com_10915_123'
# 'Latin American Journal of Pharmacy' accessible via: 'com_10915_207'
# 'MEDPAL [Publicación cerrada]' accessible via: 'com_10915_245'
# 'Educación Médica Permanente' accessible via: 'com_10915_250'
# 'Synthesis' accessible via: 'com_10915_255'
# 'Económica' accessible via: 'com_10915_274'
# 'Journal of Computer Science & Technology' accessible via: 'com_10915_369'
# 'Relaciones Internacionales' accessible via: 'com_10915_402'
# 'Auster' accessible via: 'com_10915_440'
# 'Revista de la Facultad de Ciencias Médicas de la Universidad Nacional de La Plata [Publicación cerrada]' accessible via: 'com_10915_452'
# 'Boletín Bibliotecológico de La Plata [Publicación cerrada]' accessible via: 'com_10915_456'
# 'Orbis Tertius' accessible via: 'com_10915_461'
# 'Katatay' accessible via: 'com_10915_478'
# 'ProBiota | Serie Documentos' accessible via: 'com_10915_485'
# 'Analecta Veterinaria' accessible via: 'com_10915_510'
# 'Ecos de Grado y Posgrados [Publicación cerrada]' accessible via: 'com_10915_554'
# 'Aportes para la Integración Latinoamericana' accessible via: 'com_10915_561'
# 'Trabajos y Comunicaciones' accessible via: 'com_10915_574'
# 'Educación Física y Ciencia' accessible via: 'com_10915_606'
# 'Revista de Psicología - Primera Época [Publicación cerrada]' accessible via: 'com_10915_619'
# 'Archivos de Ciencias de la Educación' accessible via: 'com_10915_629'
# 'Olivar' accessible via: 'com_10915_645'
# 'Anuario del Instituto de Historia Argentina' accessible via: 'com_10915_661'
# 'Revista de Filosofía y Teoría Política' accessible via: 'com_10915_672'
# 'Archivos de Pedagogía y Ciencias Afines [Publicación cerrada]' accessible via: 'com_10915_688'
# 'Cuadernos de Lenguas Modernas [Publicación cerrada]' accessible via: 'com_10915_728'
# 'Boletín del Instituto de Investigaciones Educativas [Publicación cerrada]' accessible via: 'com_10915_735'
# 'Cuestiones de Sociología' accessible via: 'com_10915_741'
# 'Serie Pedagógica [Publicación cerrada]' accessible via: 'com_10915_747'
# 'Mundo Agrario' accessible via: 'com_10915_752'
# 'Sociohistórica' accessible via: 'com_10915_776'
# 'Orientación y Sociedad' accessible via: 'com_10915_795'
# 'Geograficando' accessible via: 'com_10915_806'
# 'Alp [Publicación cerrada]' accessible via: 'com_10915_814'
# 'Boletín de Historia Social Europea [Publicación cerrada]' accessible via: 'com_10915_819'
# 'Boletín del Instituto de Investigaciones Literarias [Publicación cerrada]' accessible via: 'com_10915_824'
# 'Palabra Clave' accessible via: 'com_10915_832'
# 'TE & ET' accessible via: 'com_10915_836'
# 'Románica [Publicación cerrada]' accessible via: 'com_10915_843'
# 'Humanidades [Publicación cerrada]' accessible via: 'com_10915_853'
# 'Revista de Psicología - Segunda y Tercera Época' accessible via: 'com_10915_897'
# 'Documentos de Trabajo' accessible via: 'com_10915_900'
# 'Serie Trabajos Docentes' accessible via: 'com_10915_901'
# 'Revista de Filosofía [Publicación cerrada]' accessible via: 'com_10915_903'
# 'Tarea [Publicación cerrada]' accessible via: 'com_10915_927'
# 'Humanidades - Boletín de la Facultad de Humanidades y Ciencias de la Educación [Publicación cerrada]' accessible via: 'com_10915_931'
# 'Derecho y Ciencias Sociales' accessible via: 'com_10915_940'
# 'Entrelíneas de la Política Económica' accessible via: 'com_10915_946'
# 'Tercera Época' accessible via: 'com_10915_979'
# 'Revista de la Facultad de Agronomía' accessible via: 'com_10915_983'
# 'Plurentes' accessible via: 'com_10915_998'
# 'Notas en Turismo y Economía [Publicación cerrada]' accessible via: 'com_10915_1001'
# 'El Toldo de Astier' accessible via: 'com_10915_1004'
# 'ProBiota | CoBioBo [Publicación cerrada]' accessible via: 'com_10915_1009'
# 'ProBiota | Serie Técnica y Didáctica' accessible via: 'com_10915_1012'
# 'Contribución al Estudio de las Ciencias Físicas y Matemáticas [Publicación cerrada]' accessible via: 'com_10915_1028'
# 'Journal Polytechnique ou Bulletin du Travail [Publicación cerrada]' accessible via: 'com_10915_1030'
# 'AUGMDOMUS' accessible via: 'com_10915_1032'
# 'Eventos' accessible via: 'com_10915_1038'
# 'Digitalización y preservación' accessible via: 'com_10915_18173'
# 'Especialización en Docencia Universitaria' accessible via: 'com_10915_18188'
# 'Editorial de la Universidad Nacional de La Plata (EDULP)' accessible via: 'com_10915_18248'
# 'Red de Universidades con Carreras en Informática (RedUNCI)' accessible via: 'com_10915_18267'
# 'Eventos' accessible via: 'com_10915_18269'
# 'TE&ET' accessible via: 'com_10915_18270'
# 'WICC' accessible via: 'com_10915_18336'
# 'JEITICS' accessible via: 'com_10915_18455'
# 'Arkadin' accessible via: 'com_10915_18484'
# 'Arte e Investigación' accessible via: 'com_10915_18520'
# 'Boletín de Arte' accessible via: 'com_10915_18566'
# 'CACIC' accessible via: 'com_10915_18568'
# 'Anales de la Facultad de Ciencias Jurídicas y Sociales' accessible via: 'com_10915_18892'
# 'TICEC' accessible via: 'com_10915_18939'
# 'Colección Breviarios' accessible via: 'com_10915_19614'
# 'Clang' accessible via: 'com_10915_19778'
# 'La Puerta FBA [Publicación cerrada]' accessible via: 'com_10915_19927'
# 'Relaciones de la Sociedad Argentina de Antropología' accessible via: 'com_10915_20026'
# 'Cuadernos del CISH [Publicación cerrada]' accessible via: 'com_10915_20227'
# 'Tableros' accessible via: 'com_10915_20284'
# 'Dirección General de Educación a Distancia y Tecnologías (EAD)' accessible via: 'com_10915_21328'
# 'WCC' accessible via: 'com_10915_23801'
# 'CIVE' accessible via: 'com_10915_24340'
# 'Asociación de Universidades Grupo Montevideo (AUGM)' accessible via: 'com_10915_24712'
# 'Radio Universidad Nacional de La Plata' accessible via: 'com_10915_25224'
# 'PREBI-SEDICI' accessible via: 'com_10915_25293'
# 'Revista Latinoamericana de Metodología de las Ciencias Sociales (RELMECS)' accessible via: 'com_10915_25785'
# 'Dictadura militar (1976-1983)' accessible via: 'com_10915_25913'
# 'Sociedades Precapitalistas' accessible via: 'com_10915_25988'
# 'Revista [Publicación cerrada]' accessible via: 'com_10915_26193'
# 'ProBiota | Serie Documentos Relacionados' accessible via: 'com_10915_26289'
# 'Emergencia hídrica' accessible via: 'com_10915_26450'
# 'Red de Museos de la UNLP' accessible via: 'com_10915_27268'
# 'Museo de Instrumentos Musicales "Dr. Emilio Azzarini"' accessible via: 'com_10915_27269'
# 'Archivo de la Palabra' accessible via: 'com_10915_27296'
# 'Programas' accessible via: 'com_10915_27341'
# 'Museo de Física' accessible via: 'com_10915_27347'
# 'Ciencias Administrativas' accessible via: 'com_10915_27355'
# 'Producciones' accessible via: 'com_10915_27426'
# 'Música' accessible via: 'com_10915_27428'
# 'Academia Nacional de Agronomía y Veterinaria (ANAV)' accessible via: 'com_10915_27489'
# 'Anales de la ANAV' accessible via: 'com_10915_27492'
# 'Importaciones' accessible via: 'com_10915_27909'
# 'Importación S 2013' accessible via: 'com_10915_27910'
# 'Clío & Asociados' accessible via: 'com_10915_29089'
# 'Laboratorio de Investigaciones en Etnografía Aplicada (LINEA)' accessible via: 'com_10915_29186'
# 'Fondos de la Biblioteca del Departamento de Física' accessible via: 'com_10915_29272'
# 'Questión' accessible via: 'com_10915_29475'
# 'Otras colecciones' accessible via: 'com_10915_29537'
# 'Nanotecnología' accessible via: 'com_10915_29542'
# 'Estrategias - Psicoanálisis y Salud Mental' accessible via: 'com_10915_30560'
# 'Los Trabajos y los Días' accessible via: 'com_10915_31525'
# 'Oficios Terrestres' accessible via: 'com_10915_32748'
# 'Estudios del Hábitat' accessible via: 'com_10915_32766'
# 'Cuadernos de H Ideas' accessible via: 'com_10915_32778'
# 'Tram[p]as de la Comunicación y la Cultura' accessible via: 'com_10915_32920'
# 'Jornadas de Economía Monetaria e Internacional' accessible via: 'com_10915_33539'
# 'Prospectiva [Publicación cerrada]' accessible via: 'com_10915_33635'
# 'Congreso Argentino y Latinoamericano de Educación Física y Ciencias' accessible via: 'com_10915_33653'
# 'Seminario sobre Federalismo Fiscal' accessible via: 'com_10915_33883'
# 'Recursos Educativos Abiertos' accessible via: 'com_10915_34144'
# 'Facultad de Informática' accessible via: 'com_10915_34145'
# 'Documentos de trabajo' accessible via: 'com_10915_34186'
# 'Asamblea General de ISTEC' accessible via: 'com_10915_34520'
# 'Jornadas de Investigación en Filosofía' accessible via: 'com_10915_35147'
# 'Presidencia' accessible via: 'com_10915_35913'
# 'Dirección de Vinculación Tecnológica' accessible via: 'com_10915_35914'
# 'Instituto de Investigaciones Tecnológicas para Redes y Equipos Eléctricos (IITREE)' accessible via: 'com_10915_36026'
# 'Facultad de Humanidades y Ciencias de la Educación' accessible via: 'com_10915_36045'
# 'Instituto de Relaciones Internacionales (IRI)' accessible via: 'com_10915_36178'
# 'Colección Max Kohl' accessible via: 'com_10915_36210'
# 'Boletines' accessible via: 'com_10915_36531'
# 'Boletín Informativo del CENSUD' accessible via: 'com_10915_36534'
# 'Eventos' accessible via: 'com_10915_36806'
# 'Encuentros del Centro de Reflexión en Política Internacional (CERPI)' accessible via: 'com_10915_36807'
# 'Facultad de Ciencias Veterinarias' accessible via: 'com_10915_36877'
# 'Congresos de Relaciones Internacionales' accessible via: 'com_10915_36926'
# 'Jornadas de Medio Oriente' accessible via: 'com_10915_36928'
# 'Facultad de Trabajo Social' accessible via: 'com_10915_36980'
# 'Otras colecciones' accessible via: 'com_10915_37069'
# 'Ciencias Morfológicas' accessible via: 'com_10915_37233'
# 'Facultad de Ciencias Económicas' accessible via: 'com_10915_37598'
# 'Facultad de Ciencias Naturales y Museo' accessible via: 'com_10915_37665'
# 'Facultad de Ciencias Médicas' accessible via: 'com_10915_37668'
# 'Secretaría de Arte y Cultura' accessible via: 'com_10915_37729'
# 'Jornadas Nacionales de Investigación en Arte en Argentina' accessible via: 'com_10915_38262'
# 'Sociedad Argentina de Informática (SADIO)' accessible via: 'com_10915_38367'
# 'Jornadas Argentinas de Informática e Investigación Operativa (JAIIO)' accessible via: 'com_10915_38369'
# 'XLIII Jornadas Argentinas de Informática e Investigación Operativa (43 JAIIO)' accessible via: 'com_10915_38371'
# 'Investigación Joven' accessible via: 'com_10915_38969'
# 'Jornadas de Investigación en Disciplinas Artísticas y Proyectuales (JIDAP)' accessible via: 'com_10915_38981'
# 'Conclusiones Analíticas' accessible via: 'com_10915_39103'
# 'Dramatiza La Plata [Publicación cerrada]' accessible via: 'com_10915_39960'
# 'Doble Vía' accessible via: 'com_10915_40378'
# 'Niños, Menores e Infancias' accessible via: 'com_10915_41014'
# 'Laboratorio de Investigación de Sistemas Ecológicos y Ambientales (LISEA)' accessible via: 'com_10915_41015'
# 'Jornadas de Adscriptxs y Becarixs del CINIG' accessible via: 'com_10915_41023'
# 'Salas Museo de la Biblioteca Pública' accessible via: 'com_10915_41027'
# 'Extensión en Red' accessible via: 'com_10915_41226'
# 'Revista Argentina de Estudios de Juventud' accessible via: 'com_10915_41228'
# 'Laboratorio para el Estudio de la Experiencia Musical (LEEM)' accessible via: 'com_10915_41378'
# 'Jornadas de Filología y Lingüística' accessible via: 'com_10915_42147'
# 'Radiofotos' accessible via: 'com_10915_42414'
# 'Econo' accessible via: 'com_10915_42607'
# 'Nimio' accessible via: 'com_10915_42782'
# 'Bachillerato de Bellas Artes' accessible via: 'com_10915_42863'
# 'Facultad de Ciencias Agrarias y Forestales' accessible via: 'com_10915_43021'
# 'Facultad de Ciencias Jurídicas y Sociales' accessible via: 'com_10915_43025'
# 'Maíz' accessible via: 'com_10915_43051'
# 'Anuario de Investigaciones' accessible via: 'com_10915_43371'
# 'ProBiota | Serie Arte y Sociedad' accessible via: 'com_10915_44077'
# '47 al Fondo' accessible via: 'com_10915_44146'
# 'Revista de Investigaciones en Técnica Vocal' accessible via: 'com_10915_44672'
# 'Conferencia Internacional BIREDIAL-ISTEC' accessible via: 'com_10915_44725'
# 'Planes estratégicos' accessible via: 'com_10915_45052'
# 'Centro de Arte Experimental Vigo' accessible via: 'com_10915_45652'
# 'Revistas' accessible via: 'com_10915_45654'
# 'Boletín Informativo de la Cátedra Brasil' accessible via: 'com_10915_45790'
# 'Museo' accessible via: 'com_10915_46375'
# 'Letras' accessible via: 'com_10915_46575'
# 'Bit & Byte' accessible via: 'com_10915_46701'
# 'Jornadas de Investigación del Centro de Investigaciones Geográficas y del Departamento de Geografía' accessible via: 'com_10915_46995'
# 'Anuarios' accessible via: 'com_10915_47622'
# 'Jornadas de Poéticas de la Literatura Argentina para Niñ@s' accessible via: 'com_10915_48037'
# 'Eventos' accessible via: 'com_10915_48593'
# 'III Jornadas de TIC e Innovación en el Aula' accessible via: 'com_10915_48594'
# 'Ponencias' accessible via: 'com_10915_48595'
# 'Trayectorias Universitarias' accessible via: 'com_10915_48969'
# 'METAL' accessible via: 'com_10915_49539'
# 'Aletheia' accessible via: 'com_10915_50277'
# 'Puertas Abiertas' accessible via: 'com_10915_50294'
# 'Abreletras-Psicodiagnóstico [Publicación cerrada]' accessible via: 'com_10915_51212'
# 'Nexo [Publicación cerrada]' accessible via: 'com_10915_51298'
# 'Actas de Periodismo y Comunicación' accessible via: 'com_10915_51945'
# 'XLIV Jornadas Argentinas de Informática e Investigación Operativa (44 JAIIO)' accessible via: 'com_10915_51948'
# 'Biología Acuática' accessible via: 'com_10915_52925'
# 'Facultad de Periodismo y Comunicación Social' accessible via: 'com_10915_53056'
# 'Instituto de Historia, Teoría y Praxis de la Arquitectura y la Ciudad (HITEPAC)' accessible via: 'com_10915_53279'
# 'Revista de Estudios Regionales y Mercado de Trabajo [Publicación cerrada]' accessible via: 'com_10915_53659'
# 'Bold' accessible via: 'com_10915_53696'
# 'Epistemus' accessible via: 'com_10915_53843'
# 'Dirección General de Educación a Distancia y Tecnologías' accessible via: 'com_10915_54317'
# 'Improntas de la Historia y la Comunicación' accessible via: 'com_10915_54928'
# 'Instituto de Investigaciones y Políticas del Ambiente Construido (IIPAC)' accessible via: 'com_10915_55263'
# 'Con X' accessible via: 'com_10915_55315'
# 'Revista Derechos en Acción (ReDeA)' accessible via: 'com_10915_55509'
# 'Octante' accessible via: 'com_10915_55620'
# 'Banco de Tesis (tesis de grado)' accessible via: 'com_10915_56546'
# 'XLV Jornadas Argentinas de Informática e Investigación Operativa (45 JAIIO)' accessible via: 'com_10915_56802'
# 'Seminario de Economía' accessible via: 'com_10915_56806'
# 'Perspectivas en Educación Física' accessible via: 'com_10915_56861'
# 'Apuntes de Comunicación, Educación y Discurso' accessible via: 'com_10915_57821'
# 'Instituto de Integración Latinoamericana (IIL)' accessible via: 'com_10915_58635'
# 'Encuentro Nacional sobre Ciudad, Arquitectura y Construcción Sustentable' accessible via: 'com_10915_59229'
# 'No se sabe' accessible via: 'com_10915_59332'
# 'Municipalidad de Berisso' accessible via: 'com_10915_59435'
# 'Dirección de Cultura' accessible via: 'com_10915_59438'
# 'Instituto de Investigaciones en Humanidades y Ciencias Sociales (IdIHCS)' accessible via: 'com_10915_59889'
# 'Proyectos de investigación' accessible via: 'com_10915_59892'
# 'Jornadas de Investigación, Transferencia y Extensión de la Facultad de Ingeniería' accessible via: 'com_10915_59911'
# 'XLII Jornadas Argentinas de Informática e Investigación Operativa (42 JAIIO)' accessible via: 'com_10915_60182'
# 'UID en Óptica, Procesamiento de Imágenes y Metrología Óptica (OPTIMO)' accessible via: 'com_10915_60200'
# 'Coloquio Internacional del Centro de Estudios Helénicos' accessible via: 'com_10915_60216'
# 'Anuario Temas en Psicología' accessible via: 'com_10915_60248'
# 'Armiliar' accessible via: 'com_10915_60251'
# 'Taller de Indicadores de Evaluación de Bibliotecas' accessible via: 'com_10915_60271'
# 'Congreso Nacional de Derecho Agrario Provincial' accessible via: 'com_10915_60333'
# 'Congreso Internacional de Investigación de la Facultad de Psicología' accessible via: 'com_10915_60541'
# 'Jornadas de Trabajo sobre Exilios Políticos del Cono Sur en el siglo XX' accessible via: 'com_10915_60621'
# 'Jornadas CINIG de Estudios de Género y Feminismos' accessible via: 'com_10915_60627'
# 'Instituto de Investigaciones en Electrónica, Control y Procesamiento de Señales (LEICI)' accessible via: 'com_10915_60640'
# 'Jornadas de Intercambio y Reflexión acerca de la Investigación en Bibliotecología' accessible via: 'com_10915_60675'
# 'Jornadas del Doctorado en Geografía' accessible via: 'com_10915_60680'
# 'Jornadas de Género y Diversidad Sexual (GEDIS)' accessible via: 'com_10915_60772'
# 'Congreso Internacional de Literatura y Cultura Españolas Contemporáneas' accessible via: 'com_10915_60775'
# 'Revista de Interés Público (ReDIP)' accessible via: 'com_10915_60853'
# 'Jornadas de Intercambio de Experiencias' accessible via: 'com_10915_60862'
# 'Jornadas Internas de Español como Lengua Segunda y Extranjera' accessible via: 'com_10915_61026'
# 'Jornadas de Sociología de la UNLP' accessible via: 'com_10915_61030'
# 'Pensando al Filo' accessible via: 'com_10915_61060'
# 'Libros' accessible via: 'com_10915_61066'
# 'Jornadas sobre las Prácticas Docentes en la Universidad Pública' accessible via: 'com_10915_61081'
# 'UID en Investigación en Metodologías Alternativas para la Enseñanza de las Ciencias (IMAPEC)' accessible via: 'com_10915_61133'
# 'Boletín Informe Integrar' accessible via: 'com_10915_61192'
# 'Jornadas de Estudios Clásicos y Medievales' accessible via: 'com_10915_61208'
# 'Congreso Internacional Orbis Tertius de Teoría y Crítica Literaria' accessible via: 'com_10915_61228'
# 'Observatorio de Relaciones Económicas Internacionales (OREI)' accessible via: 'com_10915_61303'
# 'Jornadas de Enseñanza e Investigación Educativa en el campo de las Ciencias Exactas y Naturales' accessible via: 'com_10915_61535'
# 'Descentrada' accessible via: 'com_10915_61646'
# 'Jornadas Nacionales de TIC e Innovación en el Aula' accessible via: 'com_10915_61697'
# 'Congreso de Museos Universitarios' accessible via: 'com_10915_61704'
# 'Jornada de Investigación y Encuentro de Becarios de Investigación de la Facultad de Psicología' accessible via: 'com_10915_61771'
# 'Pórtico - Encuentro de Ciencia Ficción' accessible via: 'com_10915_61827'
# 'Jornadas de Literatura para Niños y su Enseñanza' accessible via: 'com_10915_61910'
# 'Departamento de Ciencias Biológicas' accessible via: 'com_10915_61945'
# 'Dios y el Hombre' accessible via: 'com_10915_62157'
# 'Cátedra Libre Ciencia, Política y Sociedad' accessible via: 'com_10915_62188'
# 'Grupo de Aplicaciones Matemáticas y Estadísticas de la Facultad de Ingeniería (GAMEFI)' accessible via: 'com_10915_62330'
# 'Contacto Rural' accessible via: 'com_10915_62489'
# '46 Jornadas Argentinas de Informática e Investigación Operativa (JAIIO)-43 Conferencia Latinoamericana de Informática (CLEI)' accessible via: 'com_10915_62711'
# 'Jornadas de Actualización en Prácticas Odontológicas Integradas SEPOI' accessible via: 'com_10915_62901'
# 'Revista de la Facultad de Odontología' accessible via: 'com_10915_62996'
# 'EnTornos' accessible via: 'com_10915_63111'
# 'UIDET en Gestión Ambiental (UIDET GA)' accessible via: 'com_10915_63186'
# 'Hilvanando Experiencias' accessible via: 'com_10915_63255'
# 'Laboratorio de Fisiología Reproductiva (LAFIRE)' accessible via: 'com_10915_63361'
# 'Jornadas de Investigación, Docencia, Extensión y Ejercicio Profesional (JIDEEP)' accessible via: 'com_10915_63515'
# 'Voces Emergentes' accessible via: 'com_10915_63732'
# 'Centro de Estudios Integrales de la Dinámica Exógena (CEIDE)' accessible via: 'com_10915_63815'
# 'Colección Territorios' accessible via: 'com_10915_63858'
# 'UIDET en Hidrología (UIDET Hidrología)' accessible via: 'com_10915_64365'
# 'Revista del Museo de La Plata' accessible via: 'com_10915_64778'
# 'IV Jornadas de TIC e Innovación en el Aula' accessible via: 'com_10915_64987'
# 'Ponencias' accessible via: 'com_10915_65087'
# 'Laboratorio de Análisis de Imágenes (LAI)' accessible via: 'com_10915_65186'
# 'Laboratorio de Ensayos y Mediciones Eléctricas (LEME)' accessible via: 'com_10915_65188'
# 'Colegio Nacional "Rafael Hernández"' accessible via: 'com_10915_65311'
# 'Departamento de Química' accessible via: 'com_10915_65470'
# 'Centro de Investigación y Desarrollo en Fermentaciones Industriales (CINDEFI)' accessible via: 'com_10915_65471'
# 'Congreso Internacional de Enseñanza y Producción de las Artes en América Latina' accessible via: 'com_10915_65535'
# 'Cátedra Libre de Musicoterapia' accessible via: 'com_10915_65738'
# 'Instituto Malvinas' accessible via: 'com_10915_65904'
# 'Centro de Investigaciones en Fitopatología (CIDEFI)' accessible via: 'com_10915_66162'
# 'Jornadas Estudiantiles de Investigación en Disciplinas Artísticas y Proyectuales (JEIDAP)' accessible via: 'com_10915_66227'
# 'Sección Paleontología' accessible via: 'com_10915_66240'
# 'Laboratorio de Virología (LAVIR)' accessible via: 'com_10915_66348'
# 'Sección Zoología' accessible via: 'com_10915_66435'
# 'Laboratorio de Investigaciones en Madera (LIMAD)' accessible via: 'com_10915_66554'
# 'Sección Geología' accessible via: 'com_10915_66766'
# 'Sección Antropología' accessible via: 'com_10915_66852'
# 'Grupo Fluidodinámica Computacional (GFC)' accessible via: 'com_10915_66906'
# 'Centro de Investigación y Desarrollo en Criotecnología de Alimentos (CIDCA)' accessible via: 'com_10915_67059'
# 'Instituto de Limnología "Dr. Raúl A. Ringuelet" (ILPLA)' accessible via: 'com_10915_67181'
# 'Dirección de Asuntos Municipales (DAM)' accessible via: 'com_10915_67554'
# 'Sección Botánica' accessible via: 'com_10915_67594'
# 'REVCOM' accessible via: 'com_10915_67850'
# 'Museo de Astronomía y Geofísica' accessible via: 'com_10915_68094'
# 'Red de Agricultura Familiar' accessible via: 'com_10915_68117'
# 'Diálogos del Consejo Social [Publicación cerrada]' accessible via: 'com_10915_68414'
# 'Revista de la Universidad' accessible via: 'com_10915_68438'
# 'Proyectos de Investigación Orientada (PIO)' accessible via: 'com_10915_68502'
# 'Extensión' accessible via: 'com_10915_68506'
# 'Período 2004-2007' accessible via: 'com_10915_68578'
# 'Período 2007-2010' accessible via: 'com_10915_68582'
# 'Período 2010-2014' accessible via: 'com_10915_68584'
# 'Período 2014-2018' accessible via: 'com_10915_68595'
# 'Período 2018-2022' accessible via: 'com_10915_68599'
# 'Ciencia, Tecnología y Política' accessible via: 'com_10915_68887'
# 'Jornadas de Investigación “Ríos urbanos. Nuevas perspectivas para el estudio, diseño y gestión de los territorios fluviales"' accessible via: 'com_10915_69452'
# 'Grupo de Ciencias Planetarias (GCP)' accessible via: 'com_10915_70335'
# 'XLVII Jornadas Argentinas de Informática e Investigación Operativa (47 JAIIO)' accessible via: 'com_10915_70630'
# 'Centro de Producción Multimedial (CEPROM)' accessible via: 'com_10915_70665'
# 'Simposio Regional de Investigación Contable' accessible via: 'com_10915_70739'
# 'Congreso Regional de Tecnología en Arquitectura (CRETA)' accessible via: 'com_10915_71119'
# 'Proyecciones' accessible via: 'com_10915_71226'
# 'Otros proyectos' accessible via: 'com_10915_71290'
# 'Grupo Choiols - Astronomía a ras del suelo' accessible via: 'com_10915_71291'
# 'Bachillerato de Bellas Artes "Francisco A. De Santo"' accessible via: 'com_10915_71503'
# 'Documentos institucionales' accessible via: 'com_10915_71561'
# 'Hilo_s Documentales' accessible via: 'com_10915_71623'
# 'UID Grupo de Transporte Aéreo - Grupo de Ingeniería Aplicada a la Industria (GTA-GIAI)' accessible via: 'com_10915_71787'
# 'Centro de Investigaciones Urbanas y Territoriales (CIUT)' accessible via: 'com_10915_72346'
# 'Informes de la Unidad de Auditoría Interna (UAI)' accessible via: 'com_10915_72466'
# 'Consorcio Iberoamericano de Educación en Ciencia y Tecnología (ISTEC)' accessible via: 'com_10915_72659'
# 'Eventos' accessible via: 'com_10915_72662'
# 'Secretaría de Planeamiento, Obras y Servicios' accessible via: 'com_10915_72918'
# 'Asociación Argentina de Astronomía' accessible via: 'com_10915_72926'
# 'Boletín de la Asociación Argentina de Astronomía' accessible via: 'com_10915_72927'
# 'Instituto de Botánica "Dr. Carlos Spegazzini"' accessible via: 'com_10915_72964'
# 'Centro de Investigación y Desarrollo en Ciencias Aplicadas "Dr. Jorge J. Ronco" (CINDECA)' accessible via: 'com_10915_73160'
# 'Documentos institucionales' accessible via: 'com_10915_73380'
# 'Documentos institucionales' accessible via: 'com_10915_73381'
# 'Documentos institucionales' accessible via: 'com_10915_73383'
# 'Liceo "Víctor Mercante"' accessible via: 'com_10915_73404'
# 'Documentos institucionales' accessible via: 'com_10915_73410'
# 'Documentos institucionales' accessible via: 'com_10915_73412'
# 'Documentos institucionales' accessible via: 'com_10915_73414'
# 'Documentos institucionales' accessible via: 'com_10915_73416'
# 'Documentos institucionales' accessible via: 'com_10915_73418'
# 'Documentos institucionales' accessible via: 'com_10915_73420'
# 'Documentos institucionales' accessible via: 'com_10915_73424'
# 'Documentos institucionales' accessible via: 'com_10915_73426'
# 'Secretaría de Extensión' accessible via: 'com_10915_73427'
# 'Documentos institucionales' accessible via: 'com_10915_73429'
# 'Proyectos de extensión' accessible via: 'com_10915_73430'
# 'Documentos institucionales' accessible via: 'com_10915_73432'
# 'Documentos institucionales' accessible via: 'com_10915_73434'
# 'Documentos institucionales' accessible via: 'com_10915_73437'
# 'Documentos institucionales' accessible via: 'com_10915_73439'
# 'Documentos institucionales' accessible via: 'com_10915_73441'
# 'Documentos institucionales' accessible via: 'com_10915_73443'
# 'Documentos institucionales' accessible via: 'com_10915_73445'
# 'Documentos institucionales' accessible via: 'com_10915_73447'
# 'Centro de Estudios Parasitológicos y de Vectores (CEPAVE)' accessible via: 'com_10915_73450'
# 'Instituto de Investigaciones Bioquímicas de La Plata “Profesor Doctor Rodolfo R. Brenner” (INIBIOLP)' accessible via: 'com_10915_73455'
# 'Proyectos de Extensión' accessible via: 'com_10915_73523'
# 'Centro de Endocrinología Experimental y Aplicada (CENEXA)' accessible via: 'com_10915_73646'
# 'Museo de Química y Farmacia' accessible via: 'com_10915_73757'
# 'UIDET Formulación y Evaluación de Proyectos (FyEP)' accessible via: 'com_10915_73811'
# 'Departamento de Física' accessible via: 'com_10915_73813'
# 'Quantum Information Research Group (QILP)' accessible via: 'com_10915_73814'
# 'Anales de Medicina Interna [Publicación cerrada]' accessible via: 'com_10915_74115'
# 'Odontología se va de boca' accessible via: 'com_10915_74222'
# 'Museo de la Anexa' accessible via: 'com_10915_74300'
# 'Escuela Graduada "Joaquín V. González"' accessible via: 'com_10915_74301'
# 'Instituto de Fisiología Vegetal (INFIVE)' accessible via: 'com_10915_74321'
# 'Colección de datos astronómicos históricos de la Facultad de Ciencias Astronómicas y Geofísicas' accessible via: 'com_10915_74494'
# 'Placas fotográficas' accessible via: 'com_10915_74495'
# 'Placas espectrográficas' accessible via: 'com_10915_74497'
# 'Encuentro Internacional de Historiadores Jóvenes sobre Sociedades Precapitalistas' accessible via: 'com_10915_74535'
# 'Laboratorio de Investigación y Formación en Informática Avanzada (LIFIA)' accessible via: 'com_10915_74754'
# 'Instituto de Investigaciones Fisicoquímicas Teóricas y Aplicadas (INIFTA)' accessible via: 'com_10915_74891'
# 'Centro de Química Inorgánica "Dr. Pedro J. Aymonino" (CEQUINOR)' accessible via: 'com_10915_75001'
# 'Centro de Investigación y Desarrollo en Tecnología de Pinturas (CIDEPINT)' accessible via: 'com_10915_75492'
# 'Enfermería Universitaria' accessible via: 'com_10915_75544'
# 'Jornadas Científicas de la Facultad de Odontología' accessible via: 'com_10915_75614'
# 'Jornadas sobre Enseñanza y Aprendizaje en el Nivel Superior en Ciencias Exactas y Naturales' accessible via: 'com_10915_75952'
# 'Congreso de Música Popular' accessible via: 'com_10915_76772'
# 'Audios' accessible via: 'com_10915_76810'
# 'Congreso Internacional de Enseñanza del Derecho' accessible via: 'com_10915_76917'
# 'ProBiota | Serie Folletos [Publicación cerrada]' accessible via: 'com_10915_77252'
# 'Congreso Internacional de Victimología' accessible via: 'com_10915_77432'
# 'Avances en Energías Renovables y Medio Ambiente (AVERMA)' accessible via: 'com_10915_78060'
# '@info' accessible via: 'com_10915_78123'
# 'Revista Electrónica de Derecho Internacional Contemporáneo (REDIC)' accessible via: 'com_10915_78486'
# 'Laboratorio de Arquitectura y Hábitat Sustentable (LAyHS)' accessible via: 'com_10915_78649'
# 'Simulaciones y Observaciones de Supernovas (SOS)' accessible via: 'com_10915_79771'
# 'Documentos de Trabajo de la Secretaría de Planificación y Control Institucional' accessible via: 'com_10915_79950'
# 'Centro Interdisciplinario de Estudios Complejos (CIEC)' accessible via: 'com_10915_80012'
# 'Laboratorio de Historia de la Psicología (LabHiPsi)' accessible via: 'com_10915_80167'
# 'Congreso Argentino de Ciencia Abierta y Ciudadana (CIACIAR)' accessible via: 'com_10915_81083'
# 'El Anzuelo' accessible via: 'com_10915_81432'
# 'Biblioteca Pública' accessible via: 'com_10915_81791'
# 'Importacion S 2019' accessible via: 'com_10915_82305'
# 'Palavras' accessible via: 'com_10915_83594'
# 'Instituto de Genética Veterinaria "Ing. Fernando Noel Dulout" (IGEVET)' accessible via: 'com_10915_85416'
# 'Laboratorio de Meteorología Espacial, Atmósfera Terrestre, Geodesia, Geodinámica, Diseño de Instrumental y Astrometría (MAGGIA)' accessible via: 'com_10915_86762'
# 'Instituto de Física de Líquidos y Sistemas Biológicos (IFLySIB)' accessible via: 'com_10915_86775'
# 'Instituto de Astrofísica de La Plata (IALP)' accessible via: 'com_10915_86797'
# 'Instituto de Física La Plata (IFLP)' accessible via: 'com_10915_86802'
# 'Centro de Investigaciones Cardiovasculares "Dr. Horacio E. Cingolani" (CIC)' accessible via: 'com_10915_87262'
# 'Centro de Investigaciones Geológicas (CIG)' accessible via: 'com_10915_87332'
# 'Centro de Investigaciones Inmunológicas Básicas y Aplicadas (CINIBA)' accessible via: 'com_10915_87745'
# 'XLVIII Jornadas Argentinas de Informática e Investigación Operativa (48 JAIIO)' accessible via: 'com_10915_87788'
# 'Guay' accessible via: 'com_10915_87997'
# 'Innovación y Desarrollo Tecnológico y Social (IDTS)' accessible via: 'com_10915_88124'
# 'Ateneo Popular "Alejandro Korn"' accessible via: 'com_10915_88761'
# 'Revista de Enfermedades Infecciosas Emergentes (REIE)' accessible via: 'com_10915_89381'
# 'Facultad de Arquitectura y Urbanismo' accessible via: 'com_10915_90202'
# 'Laboratorio de Investigación en Productos Agroindustriales (LIPA)' accessible via: 'com_10915_90865'
# 'Centro de Investigaciones Ópticas (CIOp)' accessible via: 'com_10915_92916'
# 'Sección Oficial' accessible via: 'com_10915_93826'
# 'Curso de posgrado: Bibliotecas y Repositorios Digitales. Tecnología y aplicaciones' accessible via: 'com_10915_93894'
# 'Departamento de Matemática' accessible via: 'com_10915_94591'
# 'Centro de Investigaciones del Medioambiente (CIM)' accessible via: 'com_10915_95060'
# 'Escenarios' accessible via: 'com_10915_95122'
# 'Intercambios' accessible via: 'com_10915_95124'
# 'Experiencias en Extensión' accessible via: 'com_10915_95582'
# 'Boletín Electrónico de Extensión' accessible via: 'com_10915_96231'
# 'Laboratorio de Etnobotánica y Botánica Aplicada (LEBA)' accessible via: 'com_10915_96758'
# 'Jornadas de Agricultura Familiar' accessible via: 'com_10915_96929'
# 'Hipertextos' accessible via: 'com_10915_97048'
# 'Publicación Técnica y Didáctica' accessible via: 'com_10915_97170'
# 'Instituto de Recursos Minerales (INREMI)' accessible via: 'com_10915_97192'
# 'Instituto de Investigación en Informática (III-LIDI)' accessible via: 'com_10915_97611'
# 'Boletín Geografías desde el Sur' accessible via: 'com_10915_98172'
# 'Ciencias Aplicadas' accessible via: 'com_10915_98819'
# 'Grupo de Didáctica de las Ciencias' accessible via: 'com_10915_100418'
# 'Laboratorio de Investigación en Nuevas Tecnologías Informáticas (LINTI)' accessible via: 'com_10915_101063'
# 'Curso de posgrado: Seminario debate: Indicadores de la visibilidad y el impacto de la producción científica' accessible via: 'com_10915_101115'
# 'Prosecretaría de Derechos Humanos' accessible via: 'com_10915_101806'
# 'Tesis' accessible via: 'col_10915_3'
# 'Varios' accessible via: 'col_10915_4'
# 'Tesis' accessible via: 'col_10915_6'
# 'Tesis' accessible via: 'col_10915_8'
# 'Varios' accessible via: 'col_10915_9'
# 'Tesis' accessible via: 'col_10915_11'
# 'Tesis' accessible via: 'col_10915_13'
# 'Varios' accessible via: 'col_10915_14'
# 'Tesis' accessible via: 'col_10915_16'
# 'Varios' accessible via: 'col_10915_17'
# 'Tesis' accessible via: 'col_10915_19'
# 'Tesis' accessible via: 'col_10915_21'
# 'Tesis' accessible via: 'col_10915_23'
# 'Varios' accessible via: 'col_10915_24'
# 'Tesis' accessible via: 'col_10915_26'
# 'Varios' accessible via: 'col_10915_27'
# 'Varios' accessible via: 'col_10915_29'
# 'Tesis' accessible via: 'col_10915_31'
# 'Varios' accessible via: 'col_10915_32'
# 'Tesis' accessible via: 'col_10915_34'
# 'Varios' accessible via: 'col_10915_35'
# 'Tesis' accessible via: 'col_10915_37'
# 'Tesis de posgrado' accessible via: 'col_10915_39'
# 'Varios' accessible via: 'col_10915_40'
# 'Tesis' accessible via: 'col_10915_42'
# 'Varios' accessible via: 'col_10915_43'
# 'Tesis' accessible via: 'col_10915_45'
# 'Varios' accessible via: 'col_10915_46'
# 'Documentos' accessible via: 'col_10915_49'
# 'Autoarchivo' accessible via: 'col_10915_50'
# 'Volumen 01 | Número 01' accessible via: 'col_10915_53'
# 'Volumen 03 | Número 01' accessible via: 'col_10915_54'
# 'Volumen 03 | Número 02' accessible via: 'col_10915_55'
# 'Volumen 04 | Número 01' accessible via: 'col_10915_56'
# 'Volumen 05 | Número 01' accessible via: 'col_10915_57'
# 'Volumen 07 | Número 01' accessible via: 'col_10915_58'
# 'Volumen 05 | Número 02' accessible via: 'col_10915_59'
# 'Volumen 06 | Número 01' accessible via: 'col_10915_60'
# 'Volumen 08 | Número 01' accessible via: 'col_10915_61'
# 'Volumen 07 | Número 02' accessible via: 'col_10915_62'
# 'Volumen 09 | Número 01' accessible via: 'col_10915_63'
# 'Volumen 10 | Número 02' accessible via: 'col_10915_64'
# 'Volumen 02 | Número 01' accessible via: 'col_10915_65'
# 'Volumen 09 | Número 02' accessible via: 'col_10915_66'
# 'Volumen 10 | Número 01' accessible via: 'col_10915_67'
# 'Volumen 11 | Número 01' accessible via: 'col_10915_68'
# 'Volumen 12 | Número 01' accessible via: 'col_10915_69'
# 'Volumen 13 | Número 01' accessible via: 'col_10915_70'
# 'Volumen 01 | Número 01' accessible via: 'col_10915_72'
# 'Volumen 01 | Número 02' accessible via: 'col_10915_73'
# 'Volumen 01 | Número 03' accessible via: 'col_10915_74'
# 'Volumen 02 | Número 01-03' accessible via: 'col_10915_75'
# 'Volumen 02 | Número 04' accessible via: 'col_10915_76'
# 'Volumen 03 | Número 01-02' accessible via: 'col_10915_77'
# 'Volumen 03 | Número 03' accessible via: 'col_10915_78'
# 'Volumen 04 | Número 01' accessible via: 'col_10915_79'
# 'Volumen 04 | Número 02-03' accessible via: 'col_10915_80'
# 'Volumen 05 | Número 01-02' accessible via: 'col_10915_81'
# 'Contribución Especial | Número 01' accessible via: 'col_10915_82'
# 'Volumen 01' accessible via: 'col_10915_84'
# 'Volumen 02' accessible via: 'col_10915_85'
# 'Volumen 03' accessible via: 'col_10915_86'
# 'Volumen 04' accessible via: 'col_10915_87'
# 'Volumen 05' accessible via: 'col_10915_88'
# 'Volumen 06' accessible via: 'col_10915_89'
# 'Volumen 07' accessible via: 'col_10915_90'
# 'Volumen 09 | Número 01' accessible via: 'col_10915_91'
# 'Volumen 08 | Número 01' accessible via: 'col_10915_92'
# 'Volumen 10 | Número 01-02' accessible via: 'col_10915_93'
# 'Volumen 11 | Número 01-02' accessible via: 'col_10915_94'
# 'Volumen 09 | Número 02' accessible via: 'col_10915_95'
# 'Volumen 12 | Número 01' accessible via: 'col_10915_96'
# 'Volumen 13 | Número 01-02' accessible via: 'col_10915_97'
# 'Volumen 14 | Número 01' accessible via: 'col_10915_98'
# 'Volumen 14 | Número 02' accessible via: 'col_10915_99'
# 'Volumen 15 | Número 01' accessible via: 'col_10915_100'
# 'Volumen 15 | Número 02' accessible via: 'col_10915_101'
# 'Volumen 16 | Número 01' accessible via: 'col_10915_102'
# 'Volumen 16 | Número 02' accessible via: 'col_10915_103'
# 'Volumen 17 | Número 01-02' accessible via: 'col_10915_104'
# 'Volumen 18 | Número 01' accessible via: 'col_10915_105'
# 'Volumen 08 | Número 02' accessible via: 'col_10915_106'
# 'Volumen 12 | Número 02' accessible via: 'col_10915_107'
# 'Volumen 18 | Número 02' accessible via: 'col_10915_108'
# 'Volumen 19 | Número 01' accessible via: 'col_10915_109'
# 'Volumen 19 | Número 02' accessible via: 'col_10915_110'
# 'Volumen 20 | Número 01' accessible via: 'col_10915_111'
# 'Volumen 20 | Número 02' accessible via: 'col_10915_112'
# 'Volumen 21 | Número 01' accessible via: 'col_10915_113'
# 'Volumen 21 | Número 02' accessible via: 'col_10915_114'
# 'Volumen 22 | Número 01' accessible via: 'col_10915_115'
# 'Volumen 22 | Número 02' accessible via: 'col_10915_116'
# 'Volumen 23 | Número 01' accessible via: 'col_10915_117'
# 'Volumen 23 | Número 02' accessible via: 'col_10915_118'
# 'Volumen 24 | Número 01' accessible via: 'col_10915_119'
# 'Volumen 24 | Número 02' accessible via: 'col_10915_120'
# 'Volumen 25 | Número 01' accessible via: 'col_10915_121'
# 'Volumen 25 | Número 02' accessible via: 'col_10915_122'
# 'vol. 21, no. 01' accessible via: 'col_10915_124'
# 'vol. 21, no. 02' accessible via: 'col_10915_125'
# 'vol. 21, no. 03' accessible via: 'col_10915_126'
# 'vol. 21, no. 04' accessible via: 'col_10915_127'
# 'vol. 22, no. 01' accessible via: 'col_10915_128'
# 'vol. 22, no. 02' accessible via: 'col_10915_129'
# 'vol. 22, no. 03' accessible via: 'col_10915_130'
# 'vol. 22, no. 04' accessible via: 'col_10915_131'
# 'vol. 23, no. 01' accessible via: 'col_10915_132'
# 'vol. 23, no. 02' accessible via: 'col_10915_133'
# 'vol. 23, no. 03' accessible via: 'col_10915_134'
# 'vol. 23, no. 04' accessible via: 'col_10915_135'
# 'vol. 24, no. 01' accessible via: 'col_10915_136'
# 'vol. 24, no. 02' accessible via: 'col_10915_137'
# 'vol. 24, no. 03' accessible via: 'col_10915_138'
# 'vol. 24, no. 04' accessible via: 'col_10915_139'
# 'vol. 25, no. 01' accessible via: 'col_10915_140'
# 'vol. 25, no. 02' accessible via: 'col_10915_141'
# 'vol. 25, no. 03' accessible via: 'col_10915_142'
# 'vol. 25, no. 04' accessible via: 'col_10915_143'
# 'vol. 19, no. 01' accessible via: 'col_10915_144'
# 'vol. 19, no. 02' accessible via: 'col_10915_145'
# 'vol. 19, no. 03' accessible via: 'col_10915_146'
# 'vol. 19, no. 04' accessible via: 'col_10915_147'
# 'vol. 20, no. 01' accessible via: 'col_10915_148'
# 'vol. 20, no. 02' accessible via: 'col_10915_149'
# 'vol. 20, no. 03' accessible via: 'col_10915_150'
# 'vol. 20, no. 04' accessible via: 'col_10915_151'
# 'vol. 17, no. 01' accessible via: 'col_10915_152'
# 'vol. 17, no. 02' accessible via: 'col_10915_153'
# 'vol. 17, no. 03' accessible via: 'col_10915_154'
# 'vol. 17, no. 04' accessible via: 'col_10915_155'
# 'vol. 18, no. 01' accessible via: 'col_10915_156'
# 'vol. 18, no. 02' accessible via: 'col_10915_157'
# 'vol. 18, no. 03' accessible via: 'col_10915_158'
# 'vol. 18, no. 04' accessible via: 'col_10915_159'
# 'vol. 14, no. 01' accessible via: 'col_10915_160'
# 'vol. 14, no. 02' accessible via: 'col_10915_161'
# 'vol. 14, no. 03' accessible via: 'col_10915_162'
# 'vol. 14, no. 04' accessible via: 'col_10915_163'
# 'vol. 15, no. 01' accessible via: 'col_10915_164'
# 'vol. 15, no. 02' accessible via: 'col_10915_165'
# 'vol. 15, no. 03' accessible via: 'col_10915_166'
# 'vol. 15, no. 04' accessible via: 'col_10915_167'
# 'vol. 16, no. 01' accessible via: 'col_10915_168'
# 'vol. 16, no. 02' accessible via: 'col_10915_169'
# 'vol. 16, no. 03' accessible via: 'col_10915_170'
# 'vol. 16, no. 04' accessible via: 'col_10915_171'
# 'vol. 12, no. 01' accessible via: 'col_10915_172'
# 'vol. 12, no. 02' accessible via: 'col_10915_173'
# 'vol. 12, no. 03' accessible via: 'col_10915_174'
# 'vol. 13, no. 01' accessible via: 'col_10915_175'
# 'vol. 13, no. 02' accessible via: 'col_10915_176'
# 'vol. 13, no. 03' accessible via: 'col_10915_177'
# 'vol. 11, no. 01' accessible via: 'col_10915_178'
# 'vol. 11, no. 02' accessible via: 'col_10915_179'
# 'vol. 11, no. 03' accessible via: 'col_10915_180'
# 'vol. 10, no. 01' accessible via: 'col_10915_181'
# 'vol. 10, no. 02' accessible via: 'col_10915_182'
# 'vol. 10, no. 03' accessible via: 'col_10915_183'
# 'vol. 09, no. 01' accessible via: 'col_10915_184'
# 'vol. 09, no. 02' accessible via: 'col_10915_185'
# 'vol. 09, no. 03' accessible via: 'col_10915_186'
# 'vol. 08, no. 01' accessible via: 'col_10915_187'
# 'vol. 08, no. 02' accessible via: 'col_10915_188'
# 'vol. 08, no. 03' accessible via: 'col_10915_189'
# 'vol. 07, no. 01' accessible via: 'col_10915_190'
# 'vol. 07, no. 02' accessible via: 'col_10915_191'
# 'vol. 07, no. 03' accessible via: 'col_10915_192'
# 'vol. 06, no. 01' accessible via: 'col_10915_193'
# 'vol. 06, no. 02' accessible via: 'col_10915_194'
# 'vol. 06, no. 03' accessible via: 'col_10915_195'
# 'vol. 05, no. 01' accessible via: 'col_10915_196'
# 'vol. 05, no. 02' accessible via: 'col_10915_197'
# 'vol. 05, no. 03' accessible via: 'col_10915_198'
# 'vol. 04, no. 01' accessible via: 'col_10915_199'
# 'vol. 04, no. 02' accessible via: 'col_10915_200'
# 'vol. 03, no. 01' accessible via: 'col_10915_201'
# 'vol. 03, no. 02' accessible via: 'col_10915_202'
# 'vol. 02, no. 01' accessible via: 'col_10915_203'
# 'vol. 02, no. 02' accessible via: 'col_10915_204'
# 'vol. 01, no. 01' accessible via: 'col_10915_205'
# 'vol. 01, no. 02' accessible via: 'col_10915_206'
# 'vol. 26, no. 01' accessible via: 'col_10915_208'
# 'vol. 26, no. 02' accessible via: 'col_10915_209'
# 'vol. 26, no. 03' accessible via: 'col_10915_210'
# 'vol. 26, no. 04' accessible via: 'col_10915_211'
# 'vol. 26, no. 05' accessible via: 'col_10915_212'
# 'vol. 26, no. 06' accessible via: 'col_10915_213'
# 'vol. 27, no. 01' accessible via: 'col_10915_214'
# 'vol. 27, no. 02' accessible via: 'col_10915_215'
# 'vol. 27, no. 03' accessible via: 'col_10915_216'
# 'vol. 27, no. 04' accessible via: 'col_10915_217'
# 'vol. 27, no. 05' accessible via: 'col_10915_218'
# 'vol. 27, no. 06' accessible via: 'col_10915_219'
# 'vol. 28, no. 01' accessible via: 'col_10915_220'
# 'vol. 28, no. 02' accessible via: 'col_10915_221'
# 'vol. 28, no. 03' accessible via: 'col_10915_222'
# 'vol. 28, no. 04' accessible via: 'col_10915_223'
# 'vol. 28, no. 05' accessible via: 'col_10915_224'
# 'vol. 28, no. 06' accessible via: 'col_10915_225'
# 'vol. 29, no. 01' accessible via: 'col_10915_226'
# 'vol. 29, no. 02' accessible via: 'col_10915_227'
# 'vol. 29, no. 03' accessible via: 'col_10915_228'
# 'vol. 29, no. 04' accessible via: 'col_10915_229'
# 'vol. 29, no. 05' accessible via: 'col_10915_230'
# 'vol. 29, no. 06' accessible via: 'col_10915_231'
# 'vol. 29, no. 07' accessible via: 'col_10915_232'
# 'vol. 29, no. 08' accessible via: 'col_10915_233'
# 'vol. 30, no. 01' accessible via: 'col_10915_234'
# 'vol. 30, no. 02' accessible via: 'col_10915_235'
# 'vol. 30, no. 03' accessible via: 'col_10915_236'
# 'vol. 30, no. 04' accessible via: 'col_10915_237'
# 'vol. 30, no. 05' accessible via: 'col_10915_238'
# 'vol. 30, no. 06' accessible via: 'col_10915_239'
# 'vol. 30, no. 07' accessible via: 'col_10915_240'
# 'vol. 30, no. 08' accessible via: 'col_10915_241'
# 'vol. 30, no. 09' accessible via: 'col_10915_242'
# 'vol. 30, no. 10' accessible via: 'col_10915_243'
# 'vol. 31, no. 01' accessible via: 'col_10915_244'
# 'Año 00 | Número 01' accessible via: 'col_10915_246'
# 'Año 01 | Número 02' accessible via: 'col_10915_247'
# 'Año 02 | Número 03' accessible via: 'col_10915_248'
# 'Año 03 | Número 04' accessible via: 'col_10915_249'
# 'Año 01 | Número 01' accessible via: 'col_10915_251'
# 'Año 01 | Número 02' accessible via: 'col_10915_252'
# 'Año 02 | Número 01' accessible via: 'col_10915_253'
# 'Año 02 | Número 02' accessible via: 'col_10915_254'
# 'Volumen 04' accessible via: 'col_10915_256'
# 'Volumen 05' accessible via: 'col_10915_257'
# 'Volumen 06' accessible via: 'col_10915_258'
# 'Volumen 03' accessible via: 'col_10915_259'
# 'Volumen 07' accessible via: 'col_10915_260'
# 'Volumen 08' accessible via: 'col_10915_261'
# 'Volumen 09' accessible via: 'col_10915_262'
# 'Volumen 10' accessible via: 'col_10915_263'
# 'Volumen 01' accessible via: 'col_10915_264'
# 'Volumen 02' accessible via: 'col_10915_265'
# 'Volumen 11' accessible via: 'col_10915_266'
# 'Volumen 12' accessible via: 'col_10915_267'
# 'Volumen 13' accessible via: 'col_10915_268'
# 'Volumen 14' accessible via: 'col_10915_269'
# 'Volumen 15' accessible via: 'col_10915_270'
# 'Volumen 16' accessible via: 'col_10915_271'
# 'Volumen 17' accessible via: 'col_10915_272'
# 'Volumen 18' accessible via: 'col_10915_273'
# 'Volumen 41 | Número 01' accessible via: 'col_10915_275'
# 'Volumen 40 | Número 01' accessible via: 'col_10915_276'
# 'Volumen 44 | Número 01-02' accessible via: 'col_10915_277'
# 'Volumen 42 | Número 01-02' accessible via: 'col_10915_278'
# 'Volumen 43 | Número 01-02' accessible via: 'col_10915_279'
# 'Volumen 41 | Número 02' accessible via: 'col_10915_280'
# 'Volumen 40 | Número 02' accessible via: 'col_10915_281'
# 'Volumen 44 | Número 03' accessible via: 'col_10915_282'
# 'Volumen 44 | Número 04' accessible via: 'col_10915_283'
# 'Volumen 39 | Número 01-02' accessible via: 'col_10915_284'
# 'Volumen 01 | Número 01' accessible via: 'col_10915_285'
# 'Volumen 01 | Número 02' accessible via: 'col_10915_286'
# 'Volumen 01 | Número 03-04' accessible via: 'col_10915_287'
# 'Volumen 02 | Número 05-06' accessible via: 'col_10915_288'
# 'Volumen 02 | Número 07-08' accessible via: 'col_10915_289'
# 'Volumen 03 | Número 09-12' accessible via: 'col_10915_290'
# 'Volumen 04 | Número 13-14' accessible via: 'col_10915_291'
# 'Volumen 04 | Número 15-16' accessible via: 'col_10915_292'
# 'Volumen 05 | Número 17-20' accessible via: 'col_10915_293'
# 'Volumen 06 | Número 21-24' accessible via: 'col_10915_294'
# 'Volumen 07 | Número 25-26' accessible via: 'col_10915_295'
# 'Volumen 07 | Número 27-28' accessible via: 'col_10915_296'
# 'Volumen 08 | Número 29-30' accessible via: 'col_10915_297'
# 'Volumen 08 | Número 31-32' accessible via: 'col_10915_298'
# 'Volumen 11 | Número 33' accessible via: 'col_10915_299'
# 'Volumen 11 | Número 34' accessible via: 'col_10915_300'
# 'Volumen 12 | Número 35' accessible via: 'col_10915_301'
# 'Volumen 12 | Número 36' accessible via: 'col_10915_302'
# 'Volumen 12 | Número 37' accessible via: 'col_10915_303'
# 'Volumen 12 | Número 38' accessible via: 'col_10915_304'
# 'Volumen 12 | Número 39' accessible via: 'col_10915_305'
# 'Volumen 13 | Número 40' accessible via: 'col_10915_306'
# 'Volumen 14 | Número 01-02' accessible via: 'col_10915_307'
# 'Volumen 14 | Número 03' accessible via: 'col_10915_308'
# 'Volumen 15 | Número 01' accessible via: 'col_10915_309'
# 'Volumen 15 | Número 02' accessible via: 'col_10915_310'
# 'Volumen 15 | Número 03' accessible via: 'col_10915_311'
# 'Volumen 16 | Número 01' accessible via: 'col_10915_312'
# 'Volumen 16 | Número 02' accessible via: 'col_10915_313'
# ...
# 'XIX Simposio Argentino de Informática y Derecho (SID 2019)' accessible via: 'col_10915_89205'
# 'XIII Simposio de Informática en el Estado (SIE 2019)' accessible via: 'col_10915_89251'
# 'II Simposio Argentino de Informática Industrial e Investigación Operativa (SIIIO 2019)' accessible via: 'col_10915_89253'
# 'VI Simposio Argentino sobre Tecnología y Sociedad (STS 2019)' accessible via: 'col_10915_89254'
# 'I Taller Argentino de Internet de las Cosas (TAIC 2019)' accessible via: 'col_10915_89256'
# 'Volumen 01 | Número 01' accessible via: 'col_10915_89383'
# 'Volumen 01 | Número 02' accessible via: 'col_10915_89384'
# 'Volumen 01 | Número 03' accessible via: 'col_10915_89385'
# 'Volumen 01 | Número 04' accessible via: 'col_10915_89387'
# 'Volumen 03 | Número 01' accessible via: 'col_10915_89389'
# 'Volumen 03 | Número 02' accessible via: 'col_10915_89392'
# 'Volumen 04' accessible via: 'col_10915_89395'
# 'Volumen 05-06' accessible via: 'col_10915_89396'
# 'Volumen 07-08' accessible via: 'col_10915_89510'
# 'Volumen 09' accessible via: 'col_10915_89511'
# 'Volumen 14' accessible via: 'col_10915_89549'
# 'Volumen 16' accessible via: 'col_10915_89565'
# 'Número 10' accessible via: 'col_10915_89627'
# 'Año 13 | Número 18' accessible via: 'col_10915_89703'
# 'Volumen 06 | Número especial' accessible via: 'col_10915_89764'
# 'XV Simposio Regional de Investigación Contable y XXV Encuentro Nacional de Investigadores Universitarios del Área Contable' accessible via: 'col_10915_89782'
# 'Volumen 06 | Número 01' accessible via: 'col_10915_89793'
# 'Volumen 06 | Número 02' accessible via: 'col_10915_89805'
# 'Año 06 | Número 06' accessible via: 'col_10915_89818'
# '2017' accessible via: 'col_10915_89883'
# 'Tomo 44 (1)' accessible via: 'col_10915_89975'
# 'Número 24' accessible via: 'col_10915_89996'
# 'Importaciones 2020 - Tanda 4 Memoria Académica' accessible via: 'col_10915_90020'
# 'Tomo 44 (2)' accessible via: 'col_10915_90064'
# 'I Congreso Internacional de Enseñanza del Derecho' accessible via: 'col_10915_90136'
# 'Volumen 14' accessible via: 'col_10915_90176'
# 'Cátedra de Instalaciones Nº 1 - CGC' accessible via: 'col_10915_90204'
# 'Volumen 13' accessible via: 'col_10915_90297'
# 'CACIC 2019' accessible via: 'col_10915_90333'
# 'TE&ET 2019' accessible via: 'col_10915_90335'
# 'Volumen 12' accessible via: 'col_10915_90370'
# 'Publicaciones' accessible via: 'col_10915_90866'
# 'Importaciones 2020 - Tanda 1 Proyectos de Extensión' accessible via: 'col_10915_90876'
# 'Convocatoria Ordinaria 2015' accessible via: 'col_10915_90992'
# 'Convocatoria Ordinaria 2016' accessible via: 'col_10915_90993'
# 'Convocatoria Ordinaria 2018' accessible via: 'col_10915_90994'
# 'Número 02' accessible via: 'col_10915_91666'
# 'Número 03' accessible via: 'col_10915_91816'
# 'Número 05' accessible via: 'col_10915_92113'
# 'Número 06' accessible via: 'col_10915_92243'
# 'Número 07' accessible via: 'col_10915_92417'
# 'Número 62' accessible via: 'col_10915_92431'
# 'Número 15' accessible via: 'col_10915_92434'
# 'Volumen 03 | Número 02' accessible via: 'col_10915_92435'
# 'Número 04' accessible via: 'col_10915_92437'
# 'Volumen 13 | Número 13' accessible via: 'col_10915_92438'
# 'Año 05 | Número 05' accessible via: 'col_10915_92440'
# 'Número 05' accessible via: 'col_10915_92444'
# 'Número 08' accessible via: 'col_10915_92587'
# 'Número 63' accessible via: 'col_10915_92592'
# 'Número 33' accessible via: 'col_10915_92758'
# 'Número 34' accessible via: 'col_10915_92759'
# 'Número 09' accessible via: 'col_10915_92762'
# 'Número 24' accessible via: 'col_10915_92804'
# 'Número 19' accessible via: 'col_10915_92838'
# 'Volumen 10' accessible via: 'col_10915_92885'
# 'Volumen 33 | Número 02' accessible via: 'col_10915_92894'
# 'Publicaciones' accessible via: 'col_10915_92917'
# 'Volumen 03 | Número 02' accessible via: 'col_10915_92981'
# 'Importaciones 2020 - Tanda 1 CONICET' accessible via: 'col_10915_92992'
# 'Año 16 | Número 49' accessible via: 'col_10915_93184'
# '2020 | Volumen 05 | Número 01' accessible via: 'col_10915_93186'
# 'Actas del Consejo Directivo' accessible via: 'col_10915_93200'
# 'Número 16' accessible via: 'col_10915_93292'
# 'Año 02 | Número 02' accessible via: 'col_10915_93294'
# 'XI Jornadas de Investigación, Docencia, Extensión y Ejercicio Profesional (XI JIDEEP)' accessible via: 'col_10915_93307'
# 'Volumen 19 | Número 01' accessible via: 'col_10915_93352'
# 'Importaciones 2020 - Tanda 2 CONICET' accessible via: 'col_10915_93436'
# 'V Congreso Argentino de AgroInformática (CAI 2013)' accessible via: 'col_10915_93441'
# 'Volumen 26 | Número 01' accessible via: 'col_10915_93513'
# '2019 | Volumen 04 | Número 02' accessible via: 'col_10915_93516'
# 'Volumen 24 | Número 30' accessible via: 'col_10915_93521'
# 'Volumen 04 | Número 03' accessible via: 'col_10915_93522'
# 'IV Congreso Argentino de Informática y Salud (CAIS 2013)' accessible via: 'col_10915_93583'
# 'Volumen 05 | Número 01' accessible via: 'col_10915_93759'
# '1895 | Volumen 06' accessible via: 'col_10915_93763'
# '1896 | Volumen 07' accessible via: 'col_10915_93765'
# '1899 | Volumen 09' accessible via: 'col_10915_93766'
# '1890-1891 | Volumen 01' accessible via: 'col_10915_93820'
# 'Tomo 01 | Número 01-06' accessible via: 'col_10915_93822'
# '1936' accessible via: 'col_10915_93828'
# 'Tomo 10 | Número 81-90' accessible via: 'col_10915_93829'
# 'Tomo 11 | Número 101-106' accessible via: 'col_10915_93832'
# '1937' accessible via: 'col_10915_93834'
# '1935' accessible via: 'col_10915_93836'
# 'X Jornadas Argentinas de Software Libre (JSL 2013)' accessible via: 'col_10915_93851'
# 'Materiales del curso' accessible via: 'col_10915_93895'
# 'Trabajos de los alumnos' accessible via: 'col_10915_93896'
# 'XVIII Jornadas de Geografía' accessible via: 'col_10915_93944'
# 'Número 64' accessible via: 'col_10915_93980'
# 'VII Jornadas de Vinculación Universidad-Industria (JUI 2013)' accessible via: 'col_10915_93981'
# 'Número 21' accessible via: 'col_10915_93982'
# 'Número 06' accessible via: 'col_10915_93983'
# 'Volumen 20 | Número 44' accessible via: 'col_10915_93986'
# 'XI Simposio Argentino de Informática y Derecho (SID 2013)' accessible via: 'col_10915_94073'
# 'VII Simposio Argentino de Informática en el Estado (SIE 2013)' accessible via: 'col_10915_94075'
# 'II Simposio Argentino de Informática Industrial (SII 2013)' accessible via: 'col_10915_94076'
# 'XXXIII Congreso de Métodos Numéricos y sus Aplicaciones (ENIEF 2017)' accessible via: 'col_10915_94105'
# 'Volumen 17 | Número 01' accessible via: 'col_10915_94179'
# 'Número 06' accessible via: 'col_10915_94182'
# 'I Congreso Internacional de Ingeniería Aplicada a la Innovación y la Educación y XXIX Asamblea General de ISTEC' accessible via: 'col_10915_94224'
# 'XI Simposio Argentino de Investigación Operativa (SIO 2013)' accessible via: 'col_10915_94283'
# 'XI Simposio sobre la Sociedad de la Información (SSI 2013)' accessible via: 'col_10915_94284'
# 'XVI Concurso de Trabajos Estudiantiles (EST 2013)' accessible via: 'col_10915_94285'
# 'V Jornadas CINIG de Estudios de Género y Feminismos y III Congreso Internacional de Identidades' accessible via: 'col_10915_94286'
# '1892 | Volumen 03' accessible via: 'col_10915_94353'
# 'Publicaciones' accessible via: 'col_10915_94592'
# 'Volumen 09 | Número 01' accessible via: 'col_10915_94626'
# 'Importaciones 2020 - Tanda 3 CONICET' accessible via: 'col_10915_94919'
# 'Publicaciones' accessible via: 'col_10915_95061'
# 'Volumen 118 | Número 02' accessible via: 'col_10915_95127'
# 'Publicaciones' accessible via: 'col_10915_95139'
# '1892 | Volumen 04' accessible via: 'col_10915_95315'
# 'Volumen 05 | Número 02' accessible via: 'col_10915_95516'
# 'Número 45' accessible via: 'col_10915_95519'
# 'Volumen 32 | Número 03' accessible via: 'col_10915_95527'
# 'Número 18' accessible via: 'col_10915_95569'
# 'Año 2012' accessible via: 'col_10915_95583'
# 'Seminario Permanente de Tesis (Cátedra II)' accessible via: 'col_10915_95729'
# 'Anuario 2019' accessible via: 'col_10915_95866'
# 'Volumen 34 | Número 01' accessible via: 'col_10915_95888'
# 'Número 65' accessible via: 'col_10915_95906'
# 'Número 10' accessible via: 'col_10915_95909'
# 'Número 51' accessible via: 'col_10915_95914'
# 'Número 27' accessible via: 'col_10915_96028'
# 'Anuario 2017' accessible via: 'col_10915_96098'
# 'Número 08' accessible via: 'col_10915_96213'
# 'Número 01' accessible via: 'col_10915_96232'
# 'Número 02' accessible via: 'col_10915_96258'
# 'Número 28' accessible via: 'col_10915_96313'
# 'Volumen 09 | Número 01' accessible via: 'col_10915_96475'
# 'Número 29' accessible via: 'col_10915_96477'
# 'Año 07 | Número 14' accessible via: 'col_10915_96505'
# 'Volumen 20 | Número 02' accessible via: 'col_10915_96523'
# 'Año 25 | Número 40' accessible via: 'col_10915_96531'
# 'Año 25 | Número 41' accessible via: 'col_10915_96629'
# 'Número 09' accessible via: 'col_10915_96650'
# 'Volumen 20 | Número 45' accessible via: 'col_10915_96652'
# '1898 | Volumen 08 | Parte 1' accessible via: 'col_10915_96678'
# '1893 | Volumen 05' accessible via: 'col_10915_96682'
# 'Número 13' accessible via: 'col_10915_96699'
# 'Publicaciones' accessible via: 'col_10915_96760'
# 'Volumen 21 | Número 01' accessible via: 'col_10915_96772'
# 'Número 22' accessible via: 'col_10915_96773'
# 'Número 12' accessible via: 'col_10915_96781'
# 'Volumen 30 | Número 01 | Número especial' accessible via: 'col_10915_96819'
# 'Volumen 21 | Número 02' accessible via: 'col_10915_96900'
# 'I Jornadas de Agricultura Familiar' accessible via: 'col_10915_96930'
# 'Número 10' accessible via: 'col_10915_96953'
# 'Anuario 2011' accessible via: 'col_10915_96970'
# 'V Coloquio Internacional del Centro de Estudios Helénicos' accessible via: 'col_10915_96989'
# 'Volumen 19 | Número 02' accessible via: 'col_10915_97041'
# 'Volumen 04 | Número 06' accessible via: 'col_10915_97053'
# 'Importaciones 2020 - Tanda 4 CONICET' accessible via: 'col_10915_97057'
# 'Número 47' accessible via: 'col_10915_97171'
# 'Publicaciones' accessible via: 'col_10915_97175'
# 'Volumen 20 | Número 01' accessible via: 'col_10915_97185'
# 'Publicaciones' accessible via: 'col_10915_97194'
# 'Volumen 21 | Número 03' accessible via: 'col_10915_97208'
# 'Número 09' accessible via: 'col_10915_97278'
# 'Volumen 05 | Número 07' accessible via: 'col_10915_97385'
# '1898 | Volumen 08 | Parte 2' accessible via: 'col_10915_97399'
# 'Número 10' accessible via: 'col_10915_97429'
# 'Año 13 | Número 53' accessible via: 'col_10915_97466'
# 'Número 08' accessible via: 'col_10915_97472'
# 'Año 13 | Número 54' accessible via: 'col_10915_97484'
# 'Número 07' accessible via: 'col_10915_97507'
# 'Número 08' accessible via: 'col_10915_97515'
# 'Año 02 | Número 02' accessible via: 'col_10915_97524'
# 'Número 03' accessible via: 'col_10915_97530'
# 'Número 30' accessible via: 'col_10915_97589'
# 'Volumen 17 | Número 02' accessible via: 'col_10915_97606'
# 'Año 01 | Número 02' accessible via: 'col_10915_97610'
# 'Publicaciones' accessible via: 'col_10915_97612'
# 'IV Coloquio Internacional del Centro de Estudios Helénicos' accessible via: 'col_10915_97643'
# 'Incidentes III | Parte I: Análisis/Orígenes' accessible via: 'col_10915_97651'
# 'Volumen 07 | Número 01' accessible via: 'col_10915_97654'
# 'Año 02 | Número 03' accessible via: 'col_10915_97655'
# 'Anuario 2018' accessible via: 'col_10915_97886'
# 'Número 31' accessible via: 'col_10915_98007'
# 'Volumen 65' accessible via: 'col_10915_98083'
# 'Año 03 | Número 04' accessible via: 'col_10915_98086'
# 'Año 2012' accessible via: 'col_10915_98174'
# 'Año 2013' accessible via: 'col_10915_98175'
# 'Volumen 07 | Número 02' accessible via: 'col_10915_98183'
# 'Volumen 05 | Número 09' accessible via: 'col_10915_98210'
# 'Volumen 18 | Número 02 (tercera época)' accessible via: 'col_10915_98214'
# 'Incidentes III | Parte I: Análisis/Consecuencias' accessible via: 'col_10915_98238'
# 'Volumen 09 | Número 02' accessible via: 'col_10915_98239'
# 'Volumen 09 | Número 18' accessible via: 'col_10915_98351'
# 'Importaciones 2020 - Tanda 1 Eventos Memoria' accessible via: 'col_10915_98378'
# 'V Jornadas de Sociología de la UNLP' accessible via: 'col_10915_98380'
# 'Año 2013' accessible via: 'col_10915_98389'
# 'Número 05' accessible via: 'col_10915_98402'
# 'Volumen 39 | Número 02' accessible via: 'col_10915_98423'
# 'Materiales y videos para acceder y trabajar en aulas virtuales' accessible via: 'col_10915_98431'
# 'Número 10' accessible via: 'col_10915_98539'
# 'Año 09 | Número 10' accessible via: 'col_10915_98559'
# 'Año 02 | Número 02' accessible via: 'col_10915_98563'
# 'Año 08 | Número 15' accessible via: 'col_10915_98576'
# 'Número 46' accessible via: 'col_10915_98769'
# 'IV Jornadas en Ciencias Aplicadas "Dr. Jorge J. Ronco"' accessible via: 'col_10915_98821'
# 'Número 29' accessible via: 'col_10915_98824'
# 'Número 122' accessible via: 'col_10915_98873'
# 'Número 006' accessible via: 'col_10915_98884'
# 'Año 09 | Número 18' accessible via: 'col_10915_99004'
# 'V Jornadas en Ciencias Aplicadas "Dr. Jorge J. Ronco"' accessible via: 'col_10915_99122'
# 'Número 30' accessible via: 'col_10915_99124'
# 'Volumen 19 | Número 02' accessible via: 'col_10915_99128'
# 'Número 04' accessible via: 'col_10915_99167'
# 'Número 04' accessible via: 'col_10915_99546'
# 'Incidentes III | Parte I: Experiencias' accessible via: 'col_10915_99600'
# 'Año 26 | Número 42' accessible via: 'col_10915_99742'
# 'Volumen 40 | Número 01' accessible via: 'col_10915_99770'
# 'Incidentes III | Parte I: Recorridos' accessible via: 'col_10915_99842'
# 'Número 11' accessible via: 'col_10915_99843'
# 'Volumen 21 | Número 02' accessible via: 'col_10915_99847'
# 'Número 44' accessible via: 'col_10915_99888'
# 'Número 45' accessible via: 'col_10915_99898'
# 'II Congreso Latinoamericano de Ingeniería de Vientos' accessible via: 'col_10915_99902'
# 'Volumen 22 | Número 01' accessible via: 'col_10915_99930'
# 'Publicaciones' accessible via: 'col_10915_100030'
# 'Tinta acústica' accessible via: 'col_10915_100070'
# 'Número 46' accessible via: 'col_10915_100110'
# 'Número 47' accessible via: 'col_10915_100118'
# 'Volumen 22 | Número 02' accessible via: 'col_10915_100122'
# 'Número 03' accessible via: 'col_10915_100192'
# 'Número 48' accessible via: 'col_10915_100246'
# 'Número 49' accessible via: 'col_10915_100247'
# 'Número 50' accessible via: 'col_10915_100248'
# 'Número 06' accessible via: 'col_10915_100312'
# 'Boletín Series - Relaciones Económicas Internacionales Argentinas' accessible via: 'col_10915_100364'
# 'Número 51' accessible via: 'col_10915_100365'
# 'Número 52' accessible via: 'col_10915_100368'
# 'Número 53' accessible via: 'col_10915_100371'
# 'Publicaciones' accessible via: 'col_10915_100419'
# 'Informes Anuales' accessible via: 'col_10915_100451'
# 'IV Jornadas de Actualización en Prácticas Odontológicas Integradas SEPOI' accessible via: 'col_10915_100574'
# 'Año 08 | Número 16' accessible via: 'col_10915_100638'
# 'Volumen 119 | Número 01' accessible via: 'col_10915_100658'
# 'Volumen 04 | Número 01' accessible via: 'col_10915_100716'
# 'Número 12' accessible via: 'col_10915_100834'
# 'Publicaciones' accessible via: 'col_10915_101065'
# 'Convenios' accessible via: 'col_10915_101102'
# 'Registros de software' accessible via: 'col_10915_101103'
# 'Materiales del Curso' accessible via: 'col_10915_101116'
# 'Tomo 45 (1)' accessible via: 'col_10915_101133'
# 'Número 25' accessible via: 'col_10915_101141'
# 'Volumen 21 | Número 46' accessible via: 'col_10915_101188'
# 'Volumen 22 | Número 01' accessible via: 'col_10915_101266'
# 'Volumen 09 | Número 02' accessible via: 'col_10915_101413'
# 'Volumen 08 | Número 13' accessible via: 'col_10915_101419'
# 'Número 08' accessible via: 'col_10915_101423'
# 'Volumen 61A' accessible via: 'col_10915_101495'
# 'Volumen 25 | Número 31' accessible via: 'col_10915_101500'
# 'Maestría en Conservación y Restauración del Patrimonio Arquitectónico y Urbano (CRIP)' accessible via: 'col_10915_101505'
# 'Volumen 61B' accessible via: 'col_10915_101509'
# 'Volumen 26 | Número 02' accessible via: 'col_10915_101614'
# 'Número 19' accessible via: 'col_10915_101762'
# 'Publicaciones' accessible via: 'col_10915_101807'
# 'Volumen 19 | Número 01 (tercera época)' accessible via: 'col_10915_101826'
# 'Número 17' accessible via: 'col_10915_101827'
# 'Incidentes III | Parte II: Pandemia(s): Virus en comunicación' accessible via: 'col_10915_101868'

# %% [markdown]
# Si se quiere recuperar los registros de un conjunto/set específico se debe indicar el parámetro set, de lo contrario se listarán todos los registros disponibles.

# %%
maxDocs=100
# Si vuelve a ejecutar esta celda, el contenido de la matriz SavedRecords se modificará.
# 2:15 h para 100k

savedRecords=[]
if allowDownloads:
    sickle = Sickle(repository_address)
    # using Dublin Core format 
    #records = sickle.ListRecords(metadataPrefix='oai_dc')
    records = sickle.ListRecords(metadataPrefix='oai_dc', set = 'snrd')
    printLog("Inicio de la descarga de registros OAI-PMH...")
    savedDocs=0
    for record in records:
        # get the PPN of the digitized work as the DC identifier will reference different (analog) manifestations
        tokens=record.header.identifier.split(":")
        tokens
        
        if savedDocs<maxDocs:
            savedDocs=savedDocs+1
            savedRecords.append(record.metadata)
            if savedDocs%1000==0:
                printLog("Downloaded %d of %d records."%(savedDocs,maxDocs))
        else:
            break
    printLog("Descarga finalizada de OAI-PMH de "+str(len(savedRecords))+" registros.")
    pickle.dump( savedRecords, open( "sedici_dc_all.pickle", "wb" ) )
else:
    printLog("Cargando registros OAI-PMH desde el disco...")
    savedRecords=pickle.load( open( "sedici_dc_all.pickle", "rb" ) )
    printLog("Done.")
# Out:
# [2020-08-11 19:36:47.353000]	Inicio de la descarga de registros OAI-PMH...
# [2020-08-11 19:36:48.093000]	Descarga finalizada de OAI-PMH de 100 registros.

# %%
record = savedRecords[34]
record["identifier"]
# Out:
# ['http://sedici.unlp.edu.ar/handle/10915/1393',
#  'https://doi.org/10.35537/10915/1393',
#  'http://digital.cic.gba.gob.ar/handle/11746/3445']

# %%
http://sedici.unlp.edu.ar/bitstream/handle/10915/1377/Documento_completo.pdf?sequence=1&isAllowed=y

# %%
record
# Out:
# {'contributor': ['Christiansen, Carlos'],
#  'creator': ['Cancelo, Gustavo Indalecio Eugenio'],
#  'date': ['1996'],
#  'description': [u'En esta tesis se realiza un estudio sobre las posibilidades de la electr\xf3nica para modelar unidades y sistemas neuronales. En particular, se proponen implementaciones de redes neuronales anal\xf3gicas. La primera a nivel microelectr\xf3nico, comprende el dise\xf1o de una neurona computacional con funci\xf3n de activaci\xf3n gaussiana. Primeramente, se demostrar\xe1 que las unidades computacionales con funci\xf3n de activaci\xf3n gaussiana forman una base para aproximadores universales de funciones continuas y discontinuas medibles. La segunda abarca la realizaci\xf3n de una neurocomputadora basada en un dispositivo neuronal anal\xf3gico. Este sistema aprovecha toda la potencia de c\xf3mputo de un procesador neuronal capaz de procesar 300 mil patrones anal\xf3gicos por segundo. El ambiente desarrollado permite que dicho procesador se convierta en el coraz\xf3n de una computadora neuronal, dentro de una computadora personal tradicional. Para ello. se desarrolla el hardware de interfaz y procesamiento necesario y el software para comunicaci\xf3n entre procesadores, conversi\xf3n an\xe1logo-digital de patrones y de manejo del sistema computador.',
#   u'Tesis digitalizada en SEDICI gracias a la colaboraci\xf3n de la Biblioteca de la Facultad de Ingenier\xeda (UNLP).',
#   u'Facultad de Ingenier\xeda'],
#  'format': ['application/pdf'],
#  'identifier': ['http://sedici.unlp.edu.ar/handle/10915/1374',
#   'https://doi.org/10.35537/10915/1374'],
#  'language': ['spa'],
#  'rights': ['info:eu-repo/semantics/openAccess',
#   'http://creativecommons.org/licenses/by-nc/4.0/',
#   'Creative Commons Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)'],
#  'subject': [u'Ingenier\xeda'],
#  'title': [u'Redes neuronales anal\xf3gicas para la computaci\xf3n paralela masiva de se\xf1ales en tiempo real'],
#  'type': ['info:eu-repo/semantics/doctoralThesis',
#   'info:ar-repo/semantics/tesis doctoral',
#   'info:eu-repo/semantics/acceptedVersion',
#   'Tesis de doctorado']}

# %%
# uncomment this cell if you want to split the image download to two different computers
# in this case, one computer will use "even_dc_all.pickle" while the other will use "odd_dc_all.pickle" in the next cell

#availableKeys=dict()
#evenRecords=[]
#oddRecords=[]

#for i,r in enumerate(savedRecords):
#    for k in r.keys():
#        if not k in availableKeys:
#            availableKeys[k]=1
#        else:
#            availableKeys[k]=availableKeys[k]+1
#    if i%2==0:
#        evenRecords.append(r)
#    else:
#        oddRecords.append(r)

#pickle.dump( evenRecords, open( "even_dc_all.pickle", "wb" ) )
#pickle.dump( oddRecords, open( "odd_dc_all.pickle", "wb" ) )

# %% [markdown]
# In the next step, all images are downloaded, downscaled and converted to the JPEG format.

# %%
# uncomment this line if you are continuing the execution of this notebook at a later point in time
#savedRecords=pickle.load( open( "save_120k_dc_all.pickle", "rb" ) )
tiffDownloadPath="https://ngcs.staatsbibliothek-berlin.de/?action=metsImage&format=jpg&metsFile=%PPN%&divID=PHYS_0001&original=true"
countSavedRecords=len(savedRecords)
printLog("Started image download and processing. This will take a while...")
#logFile = open("/Volumes/2TB_WD/sbb_images/downloadIssues.txt", "w")
logFile = open(downloadDir+"/downloadIssues.txt", "w")

# surpress PIL's DecompressionBombErrors and Warnings
Image.MAX_IMAGE_PIXELS = None

for i,record in enumerate(savedRecords):
    if i%1000==0:
        if allowDownloads:
            printLog("Downloaded %d of %d images."%(i,countSavedRecords))
    
    ppn=""
    for r in record["identifier"]:
        if r.startswith("PPN"):
            ppn=r
            break
    #if len(record["identifier"])>1:
    #    ppn=str(record["identifier"][1])
    #else:
    #    ppn=str(record["identifier"][0])
    ppnTIFF=ppn+".tif"
    ppnJPEGPAth=downloadDir+ppn+".jpg"
    #if "object" in record.keys() and allowDownloads:
    if allowDownloads:
        httpCode=200
        # prevent downloading of already present files
        if not os.path.isfile(ppnJPEGPAth) :
            tryDownload=True
            # check for the HTTP error code, maybe the file does not exist
            try:
                response=urllib.request.urlopen(tiffDownloadPath.replace("%PPN%",ppn))
            except urllib.error.HTTPError as ex:
                #print("Error with %s"%tiffDownloadPath.replace("%PPN%",ppn))
                httpCode=ex.code
                tryDownload=False
            if tryDownload:
                #if allowDownloads:
                urlinfo=urllib.request.urlretrieve(tiffDownloadPath.replace("%PPN%",ppn),downloadDir+ppnTIFF)
                img = Image.open(downloadDir+ppnTIFF)
                img.thumbnail((512,512))
                img.save(downloadDir+ppn+".jpg")
                if not keepTIFFs:
                    os.remove(downloadDir+ppnTIFF)
                #ret=subp.call(["mogrify", "-resize","512x512","-format", "jpg",downloadDir+ppnTIFF])
                #if ret!=0:
                #    print("Problem with mogrifying "+ppnTIFF)
                #    logFile.write("[MOGRIFY]: %s \n%s\n\n" % (str("Problem with mogrifying "+ppnTIFF),str("Downloaded from: "+record["object"][0])))
                #ret=subp.call(["rm",downloadDir+ppnTIFF])
                #if ret!=0:
                #    print("Problem with removing "+ppnTIFF)
                #    logFile.write("[REMOVAL]: %s\n\n" % "Problem with removing "+ppnTIFF)
            else:
                print("Problem with accessing "+ppnTIFF+ " @ "+tiffDownloadPath.replace("%PPN%",ppn)+" due to HTTP code: "+str(httpCode))
                logFile.write("[HTTP]: %s\n\n" % "Problem with accessing "+tiffDownloadPath.replace("%PPN%",ppn))
                logFile.write("\tHTTP Code: "+str(httpCode)+"\n")
                #logFile.write(str(urlinfo[1])+"\n\n")
    else:
        logFile.write("[OBJECT key missing]: %s\n\n" % str(record))
logFile.close()
print("\n")
if allowDownloads:
    printLog("Finished image download and processing.")
else:
    printLog("Skipped image download and processing.")

# %% [markdown]
# Please note that images will not be downloaded for some metadata records. This is no error because periodicals or multivolume work do not come with presentation images.

# %% [markdown]
# ### Creating a Dataframe from the Metadata Records

# %%
# load the records
printLog("Loading pickled records...")
# uncomment this line if you are continuing the execution of this notebook at a later point in time
savedRecords=pickle.load( open( "save_120k_dc_all.pickle", "rb" ) )
printLog("Finished loading pickled records.")

availableKeys=dict()

# check for all keys present in the previously downloaded dataset
for i,r in enumerate(savedRecords):
    for k in r.keys():
        if not k in availableKeys:
            availableKeys[k]=1
        else:
            availableKeys[k]=availableKeys[k]+1
    
print(availableKeys)

# create a dictionary for the records
values=dict()
# take the keys as they have found within the downloaded OAI records
keys=availableKeys.keys()
# for every metadata field, create an empty array as the content of the dictionary filed under the key 'k'
for k in keys:
    values[k]=[]
# in addition, store the PPN (the SBB's unique identifier for digitized content)    
#values["PPN"]=[]

# iterate over all saved records
for record in savedRecords:
    # we cannot iterate over the keys of record.metadata directly because not all records cotain the same fields,...
    for k in keys:
        # thus we check if the metadata field 'k' has been created above
        if k in values:
            # append the metadata fields to the dictionary created above
            # if the metadata field 'k' is not available input "None" instead
            #values[k].append(record.get(k,["None"])[0].encode('ISO-8859-1'))
            if k in record:
                value=record.get(k)[0]
                if value:
                    if value.isdigit():
                        value=int(value)
                    else:
                        #p27 value=value.encode('ISO-8859-1')
                            #value=value.encode('ISO-8859-1').decode("utf-8", "backslashreplace")
                        value=value
                    values[k].append(value)
                else:
                    values[k].append(np.nan)
            else:
                values[k].append(np.nan)
# create a data frame from the 
#p27 df=pd.DataFrame(pd.to_numeric(values,errors='coerce'))
df=pd.DataFrame(values)
df['date']=pd.to_numeric(df['date'],errors='ignore',downcast='integer')
#df=pd.DataFrame(values)
#df=df.convert_objects(convert_dates=False, convert_numeric=True, convert_timedeltas=False, copy=True)
df.shape

# %%
# creating a PPN list in CSV format is handy if you want to use it with sbbget from StabiHacks
#df.PPN.to_csv("120k_ppn_list.csv",index=False)

# in case you want to use this data frame somewhere else, here are some sample serializations
#printLog("Serializing data frame...")
# Microsoft Excel
#df.to_excel("120k_sbb_sample.xlsx")
# HDF5 format
#df.to_hdf("120k_sbb_sample.hdf5",key="sbb")
#printLog("Done.")

# %%
# if you want to continue from here, it might be a good idea to 
df=pd.read_excel("ppn_records_146000.xlsx")
df.shape

# %% [markdown]
# ## Inspecting Data

# %%
df.head()

# %%
df[df.PPN.isnull()].count()

# %% [markdown]
# Usually, we know that some columns should only contain unique values, e.g., the PPN column. Hence, it is a good starting point for the analysis to validate this hypothesis with the help of the following function.

# %%
# checks for unique values in each column
def uniqueValues(currentDataFrame):
    colNames=currentDataFrame.columns.values.tolist()
    for colName in colNames:
        print(colName+";\t\t unique values:\t"+str(len(currentDataFrame[colName].unique()))+ "\t total count: "+str(currentDataFrame[colName].count()))

uniqueValues(df)

# %% [markdown]
# Unfortunately, not all entries in the PPN column are unique. In other works, some works appear more than one time in the retrieved dataset. This is an observation we should definitely take care of later.

# %% [markdown]
# * https://www.maxmind.com/en/free-world-cities-database
# * http://www.geonames.org/export/
# * http://www.opengeocode.org/download.php#cities
# * https://en.wikipedia.org/wiki/Lists_of_cities_by_country

# %% [markdown]
# ### Classification of Data with the Help of Regular Expressions
#
# As our last observation made us sceptical about the general data quality, we should analyse the data in more detail. Regular expressions are a handy means in order to analyse columns that we expect to follow a certain internal structure or pattern.
#
# The next cell creates various regular expression to discover positive or negative numbers, different date ranges, emails, ISBN numbers or the like.

# %%
# regular expressions taken from: http://stackoverflow.com/questions/1449817/what-are-some-of-the-most-useful-regular-expressions-for-programmers
# extended by David Zellhöfer

patterns=dict()
#^ beginning of string, $ end of string, \d digits +: once or more times
patterns["positiveInteger"]="^\d+$"
patterns["negativeInteger"]="^-\d+$"
patterns["generalInteger"]="^-?\d+$"
patterns["positiveFloat"]="^\d*\.\d+$"
patterns["negativeFloat"]="^-\d*\.\d+$"
patterns["generalFloat"]="^-?\d*\.\d+$"
patterns["positiveGermanFloat"]="^\d*,\d+$"
patterns["negativeGermanFloat"]="^-\d*,\d+$"
patterns["generalGermanFloat"]="^-?\d*,\d+$"
# Date (dd mm yyyy, d/m/yyyy, etc.), in range 1000-2099 without proper February handling
patterns["dateVariant"]="^([1-9]|0[1-9]|[12][0-9]|3[01])\D([1-9]|0[1-9]|1[012])\D(1[0-9][0-9][0-9]|20[0-9][0-9])$"
patterns["year"]="^(1[0-9][0-9][0-9]|20[0-9][0-9])$"
patterns["ancientYear"]="^([0-1]?[0-9][0-9][0-9]|20[0-9][0-9])$"
patterns["century"]="^(1[0-9][Xx][Xx]|20[Xx][Xx])$"
patterns["ancientCentury"]="^([0-1]?[0-9][Xx][Xx]|20[Xx][Xx])$"
patterns["decade"]="^(1[0-9][0-9][Xx]|20[0-9][Xx])$"
patterns["ancientDecade"]="^([0-1]?[0-9][0-9][Xx]|20[0-9][Xx])$"
# year range with splitter "- / :", the splitter can be surrounded by an arbitrary amount of whitespaces (\s)
patterns["rangeYear"]="^\s*(1[0-9][0-9][0-9]|20[0-9][0-9])\s*(\-|\/|:)\s*(1[0-9][0-9][0-9]|20[0-9][0-9])\s*$"
patterns["rangeCentury"]="^\s*(1[0-9][Xx][Xx]|20[Xx][Xx])\s*(\-|\/|:)\s*(1[0-9][Xx][Xx]|20[Xx][Xx])\s*$"
patterns["rangeAncientYear"]="^\s*([0-1]?[0-9][0-9][0-9]|20[0-9][0-9])\s*(\-|\/|:)\s*(1[0-9][0-9][0-9]|20[0-9][0-9])\s*$"
patterns["rangeAncientCentury"]="^\s*([0-1]?[0-9][Xx][Xx]|20[Xx][Xx])\s*(\-|\/|:)\s*(1[0-9][Xx][Xx]|20[Xx][Xx])\s*$"
patterns["rangeYear2Digit"]="^\s*(1[0-9][0-9][0-9]|20[0-9][0-9])\s*(\-|\/|:)\s*([0-9][0-9])\s*$"
patterns["rangeDateVariant"]="^\s*([1-9]|0[1-9]|[12][0-9]|3[01])\D([1-9]|0[1-9]|1[012])\D(1[0-9][0-9][0-9]|20[0-9][0-9])\s*(\-|\/|:)\s*([1-9]|0[1-9]|[12][0-9]|3[01])\D([1-9]|0[1-9]|1[012])\D(1[0-9][0-9][0-9]|20[0-9][0-9])\s*$"

patterns["email"]="^[_]*([a-z0-9]+(\.|_*)?)+@([a-z][a-z0-9-]+(\.|-*\.))+[a-z]{2,6}$"
patterns["domain"]="^([a-z][a-z0-9-]+(\.|-*\.))+[a-z]{2,6}$"
patterns["url"]="^https?\:\/\/[a-zA-Z0-9.-]+\.[a-zA-Z]{2,3}\/?$"
patterns["ipv4"]="^(?:\d{1,3}\.){3}\d{1,3}$"
patterns["rgbHex"]="^#([a-fA-F0-9]{6}|[a-fA-F0-9]{3})$"
patterns["generalHex"]="^#[a-fA-F0-9]*$"
 
patterns["isbnPrefix"]="^ISBN(-1(?:(0)|3))?:?\x20(\s)*[0-9]+[- ][0-9]+[- ][0-9]+[- ][0-9]*[- ]*[xX0-9]$"
patterns["isbn"]="^[0-9]+[- ][0-9]+[- ][0-9]+[- ][0-9]*[- ]*[xX0-9]$"
patterns["NaN"]="^[Nn][Aa][Nn]$"

# %% [markdown]
# Now, it is time to find out if all date columns match the patterns specified above.

# %%
rowCount=0
histogram=dict()
for row in df.iterrows():
    rowCount=rowCount+1
    readDate=str(row[1]["date"])
    matchedOnce=False
    for key in patterns:
        p=re.compile(patterns[key])
        m = p.search(readDate)
        if m:
            if not key in histogram:
                histogram[key]=0
            histogram[key]=histogram[key]+1
            matchedOnce=True
        else:
            pass
    if not matchedOnce:
        print("No matches at all: "+row[1]["PPN"]+"\t for: "+str(readDate))
print("Row count: "+str(rowCount))
print(histogram)

# %%
plt.plot(*zip(*sorted(histogram.items())))

# %% [markdown]
# As expected, the matching yields a "sediment" of extreme cases that need special treatment, e.g., "1756 $ [ca. 1756]". By iterating this process, we could easily address all patterns present in the dataset.
#
# ### Inspecting Spatial Locations
#
# Because the dataset contains a lot of historical works, the _spatial_ columns deserves further attention. To get a feeling for the data, we will inspect its contents.

# %%
df.coverage.head(30)

# %% [markdown]
# Unfortunately, the spatial column does not only contain cities.  Sometimes, more than one city or a even a country is contained. Another variant uses square brackets. Additionally, specific bibliographic terminology indicate that no place of publication ([s.l.]=sine loco=without place or o.O. as its German equivalent) could be determined.

# %% [markdown]
# ### Combining Data Cleansing Utilities

# %%
class DataCleaner:
    # matches alphanumeric character and the underscore at the beginning of the string
    #Unicode flag is needed because of Asian character sets otherwise such signs would be considered as non-alphanumeric
    regEx_AlphaNum=re.compile("^\w",re.UNICODE)
    # checks for surrounding []; will match almost everything but Asian characters
    regEx_BracketText=re.compile("^\[[\w\?\.,\sßÄäÖöÜü]*\]",re.UNICODE)
    # checks for typical spellings of the "sine loco" abbreviation "s. l."
    regEx_SineLoco=re.compile("[sSoO]\s?\.\s?[lLoO]\s?\.?\s?",re.UNICODE)
    
    def __init__(self):
        pass
    
    def cleanAncientYearStrict(self,readData):
        if type(readData)==float:
            if not readData:
                return 0
            else:
                return readData
        else:
            p=re.compile(patterns["ancientYear"])
            m = p.search(str(readData))
            if m:
                firstAppearance=m.group()
                return firstAppearance
            else:
                return np.nan
            
    def cleanSpatialText(self,readData):
        returnedString=""
        # just in case we did not get a string, we use brute force and return NaN
        if type(readData)==float:
            return ""
        else:
            #readData=str(readData)
            m = self.regEx_AlphaNum.search(readData)
            # if the string does start with a bracket...
            if not m:
                #print "No matches at all: "+row[1]["PPN"]+"\t for: "+str(readData)
                m2 = self.regEx_BracketText.search(readData)
                if m2:
                    matchedGroup=m2.group()
                    #print "\tMatch: "+matchedGroup
                    m3=self.regEx_SineLoco.search(matchedGroup)
                    if m3:
                        #print "\tMatched Sine Loco: "+str(m3.group())
                        return ""
                    else:
                        matchedGroup=matchedGroup.replace("[","").replace("]","")
                        #print "\tFinal string: "+matchedGroup
                        returnedString=matchedGroup
            # otherwise, it may still be a "sine loco"
            else:
                m3=self.regEx_SineLoco.search(readData)
                if m3:
                    #print "\tMatched Sine Loco: "+str(m3.group())
                    return ""
                else:
                    # in any case, there might be brackets left
                    returnedString=readData.replace("[","").replace("]","")
        
        # remove variants of "u.a."            
        regex = re.compile("[uU]\.\s?[aA]\.\s?",re.UNICODE)
        returnedString=regex.sub("",returnedString)
        return returnedString

# %% [markdown]
# ### Cleaning Data

# %%
dc=DataCleaner()

#for row in df.iterrows():
#    print dc.cleanSpatialText(str(row[1]["spatial"]))
    
df['spatialClean'] = df.coverage.apply(dc.cleanSpatialText)
df['dateClean'] = df.date.apply(dc.cleanAncientYearStrict)

# %% [markdown]
# gate 2

# %%
df.head(30)

# %%
uniqueValues(df)

# %%
#py27 df.sort_values(by="date")

# http://stackoverflow.com/questions/40032341/pandas-sort-dataframe-by-column-with-strings-and-integers
df.groupby(df.date.apply(type) != str).apply(lambda g: g.sort('date')).reset_index(drop = True)

# %% [markdown]
# ## Using Clustering for Further Data Cleansing
# ### Example of The Things We Are Up To

# %%
words = u'Berlin Balin Cölln Köln'.split()
print(words)

print("Number of words: %i" % len(words))
for i,val in enumerate(words):
    print(str(i)+":\t "+str(val.encode('utf-8')))

# %% [markdown]
# First, we are interested in finding out whether the Jaro distance is really a distance. As you might remember from your studies, a (normalized) distance yields 1.0 a dissimilar object. Hence, the distance between "Berlin" and "Berlin" should be 0.

# %%
jaro_distance(u'Berlin',u'Berlin')

# %% [markdown]
# Obviously, it is not a distance. Therefore, we have to subtract the future results of __jaro_distance()__ from 1.0 to get a real distance score.

# %%
# http://docs.scipy.org/doc/numpy-1.10.1/reference/generated/numpy.triu_indices.html
# 2nd parameter:
# Diagonal above which to zero elements. k = 0 (the default) is the main diagonal, k < 0 is below it and k > 0 is above."""
# r= Return the indices for the upper-triangle of an (n, m) array. da m nicht angegeben ist, wird n=m angenommen
# m is not passed, hence m=n

# sagen, dass die matrix square ist!
r=np.triu_indices(n=len(words), k=1)
r

# %% [markdown]
# what does this mean?
# $$
# A=
# \begin{pmatrix}
# a_{0,0} & \underline{a_{0,1}} & \underline{a_{0,2}} & \underline{a_{0,3}} \\
# \cdot & a_{1,1} & \underline{a_{1,2}} & \underline{a_{1,3}} \\
# \cdot & \cdot & a_{2,2} & \underline{a_{2,3}} \\
# \cdot & \cdot & \cdot & a_{3,3}
# \end{pmatrix}
# $$
#
# how to interpret: $a_{0,1}$, i.e., the difference between "Berlin" and "Balin"

# %%
def d_demo(coord):
    print(coord)
    i, j = coord
    # 1- wg. Distanz (see above)
    return 1-jaro_distance(words[i], words[j])

# %%
# http://docs.scipy.org/doc/numpy-1.10.1/reference/generated/numpy.set_printoptions.html
np.set_printoptions(precision=4)

# axis (3rd parameter): 0= along y axis, 1= along x axis
r2=np.apply_along_axis(d_demo, 0, r)
r2

# %% [markdown]
# what does this mean for our matrix?
# $$
# A=
# \begin{pmatrix}
# a_{0,0} & \underline{0.1778} & \underline{0.4222} & \underline{0.3889} \\
# \cdot & a_{1,1} & \underline{0.4} & \underline{0.3667} \\
# \cdot & \cdot & a_{2,2} & \underline{0.2167} \\
# \cdot & \cdot & \cdot & a_{3,3}
# \end{pmatrix}
# $$
#
# how to interpret: $a_{0,1}$, i.e., the difference between "Berlin" and "Balin" is 0.17777778.
#
# why not the elements on the diagonal? because...

# %% [markdown]
# ### Working with Real Data
#
# first, we have to define the distance function

# %%
def d(coord):
    #print(coord)
    i, j = coord
    #py27 return 1-jaro_distance(unicode(str(words[i]), 'utf-8'), unicode(str(words[j]), 'utf-8'))
    return 1-jaro_distance(words[i],words[j])

# %%
df3=df#pd27 .sort_values(by="date")#.head(100)

uniqueSpatials=df3["spatialClean"].unique()
words=None
if demoClustering:
    words=uniqueSpatials[:100] # only consider the first 100 elements for performance reasons
else: # during normal operation, we want to consider all unique spatial names...
    words=uniqueSpatials
r=np.triu_indices(len(words), 1)

# %% [markdown]
# the next step will take some time, hence we limited the number of spatial labels before (3-4 min.)

# %%
printLog("Started calculation of distance matrix for %i words..."%len(words))
# _ is the last evaluated value in an interactive shell
# axis (3rd parameter): 0= along y axis, 1= along x axis
r2=np.apply_along_axis(d, 0, r)
printLog("Finished calculations.")

# %% [markdown]
# agglomeratives Clustering (hier nearest points, bottum-up) im gegensatz zu divisiven (top-down), das Beispiel hier nutzt den nearest point algorithm (Formel siehe https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.cluster.hierarchy.linkage.html)

# %%
Z=scipycluster.linkage(r2)

if not demoClustering:
    pickle.dump( Z, open( "cluster_hierarchy_linkage_result_without_name_clustering.pickle", "wb" ) )

#Z
# scientific notation erklären

# %% [markdown]
# i müsste Zeile sein
#
# A 4 by (n-1) matrix Z is returned. At the i-th iteration, clusters with indices Z[i, 0] and Z[i, 1] are combined to form cluster n + i. A cluster with an index less than n corresponds to one of the n original observations. The distance between clusters Z[i, 0] and Z[i, 1] is given by Z[i, 2]. The fourth value Z[i, 3] represents the number of original observations in the newly formed cluster.
#
# mehr infos: https://joernhees.de/blog/2015/08/26/scipy-hierarchical-clustering-and-dendrogram-tutorial/

# %%
#Z=pickle.load( open( "cluster_hierarchy_linkage_result.pickle", "rb" ) )
if demoClustering:
    plt.figure(figsize=(25, 10))
    plt.title('Hierarchical Clustering Dendrogram')
    plt.xlabel('sample index')
    plt.ylabel('distance')
    scipycluster.dendrogram(
        Z,
        leaf_rotation=90.,  # rotates the x axis labels
        leaf_font_size=16.,  # font size for the x axis labels
    )
    plt.show()

# %% [markdown]
# * fcluster macht aus der clusterhierarchie wiederum "flat clusters"

# %%
clusters=scipycluster.fcluster(Z, t=0.1,criterion="distance")
# 2. parameter ist abhängig von der clustering strategie, -> cophenetic distance
# see: http://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.fcluster.html
# An array of length n. T[i] is the flat cluster number to which original observation i belongs.


# https://stat.ethz.ch/R-manual/R-devel/library/stats/html/cophenetic.html
# https://en.wikipedia.org/wiki/Cophenetic
# wir erhalten für jedes unser elemente eine cluster ID
clusters

# %% [markdown]
# service functions that help to establish a linkage between the cluster IDs and human readable names

# %%
def getWordIndex(word):
    return np.where(words==word)[0]

def getClusterID(data):
#for row in df3.iterrows():
    #data=row[1]["spatialClean"]
    #wordIndex=np.where(words==data)[0]
    #if data == u"奈良".encode('utf-8'):
    #    print "China!"
    #    wordIndex=getWordIndex(data)
    #    print wordIndex
    #    print clusters[wordIndex][0]
    wordIndex=getWordIndex(data)
    if wordIndex:
        return clusters[wordIndex][0]
    else:
        return ""

# %% [markdown]
# ### Inspecting the Clustered Results Deeper

# %%
#
Z_huge=pickle.load( open( "cluster_hierarchy_linkage_result_without_name_clustering.pickle", "rb" ) )
uniqueSpatials=df3["spatialClean"].unique()
words=uniqueSpatials
len(words)

# %%
clusters=scipycluster.fcluster(Z_huge, t=0.07,criterion="distance")
clusters

# %% [markdown]
# gate 3

# %%
df3['spatialCluster'] = df3["spatialClean"].apply(getClusterID)
grp=df3.groupby("spatialCluster")
#print grp.groups.keys()
print("Number of clusters: %i" % len(grp.groups.keys()))

# %% [markdown]
# stichproben ...

# %%
grp.get_group(clusters[getWordIndex("Berlin")][0])

# %% [markdown]
# shortcut, because we are only interested in the unique names within a cluster...

# %%
grp.get_group(clusters[getWordIndex("Frankfurt/Oder")][0])["spatialClean"].unique()

# %% [markdown]
# semantisch sind die cluster natuerlich nicht korrekt...
#
# a good time for inspecting all of our clusters' contents

# %%
for key in grp.groups.keys():
    if key:
        print(key)
        print(grp.get_group(key)["spatialClean"].unique())

# %% [markdown]
# * synonym: ['Francofurti Ad Viadrum'] as a Latin translation of Frankfurt/Oder would be long to the cluster with ['Frankfurt/Main' 'Frankfurt/Oder' 'Frankfurt, Main' 'Frankfurt, O']
# * however, Frankfurt/Main and Frankfurt/Oder are to differt cities
# * ['Francofurti'] is in a 1-element cluster
# * ['C\xc3\xb6lln an der Spree'] is a synonym for Berlin
# * duplicate entries: ['Hallae Magdeburgicae  Hallae Magdeburgicae'] 1-gram und 2-gram vergleichen!
# * auf Enthaltensein von Berlin prüfen
# * St. Sankt Saint Bad als Präfix behandeln

# %%
# backup of the dataframe as we are going to remove data from the spatialClean column
pickleCompress('./picklez/df3_unclean_spatials.picklez',df3)
# if you want to continue from here, uncomment the following line
#df3=pickleDecompress('./picklez/df3_unclean_spatials.picklez')

# %% [markdown]
# ### Further Cleaning
#
# on some occasions, we have to deal with spatialClean entries that contain multiple cities

# %%
# PPN836134109 contains multiple cities
df3[df3.PPN=="PPN836134109"]

# %% [markdown]
# handle compound city names (only today's German cities to give an example)
#
# * to avoid superfluous comparisons we split the city names by their leading character

# %%
cityNameFile_DE = open('citynames.txt', 'r')
cityNGramsDE=dict()
lastLetter=""
for line in cityNameFile_DE:
    if not line.startswith("//"):
        r=line.replace("\n","").strip()
        if " " in r:
            #print r
            if not lastLetter==r[0].lower():
                lastLetter=r[0].lower()
                cityNGramsDE[lastLetter]=[]
            cityNGramsDE[lastLetter].append(r)
            #py27 cityNGramsDE[lastLetter].append(r.decode("utf-8"))

# %% [markdown]
# in case of multiple cities, we will only consider the first one

# %%
# Various test cases of city names
#s1="Frankfurt, O"
#s2='Hallae Magdeburgicae  Hallae Magdeburgicae'
#s3="Leipzig  Paris  Petersburg  London"
#s4='Franckfurt  N\xc3\xbcrnberg  Leipzig'
#s5='Freiburg i.Br. ' # not matched correctly but okay
#s6='Frankfurt/Main' 
#s7='Frankfurt, Main'

#s8='Bad Nauheim'
#s9='Rottach-Egern am Tegernsee'
#s10='Egern a. Tegernsee'
#s11="Plancy-L'Abbaye"
#s12='Bad Nauheim Sankt'
#s13="Saint Tropez"
#s14="Sankt Augustin"
#s15="Sankt-Augustin"
#s16="St.-Whatever"
#s17="St. Whatever"

def pickFirstCity(testString):
# checks if the testString contains multiple cities separated by whitespaces and returns the first city respecting city name prefixes such as Saint, St. etc.
    #py27 testString=unicode(testString,"utf-8")
    #print type(testString)
    #testString=testString.decode('unicode-escape')
    
    # matches for whitespaces that are NOT preceded by the following signs: ", ; : \ / " denoted in the regex by (?<!...)
    regex = re.compile("(?<![,;:\\\/])\s*",re.UNICODE)

    # matches various city prefix such as Saint etc.
    spatialPrefixRegExes=[]
    spatialPrefixRegExes.append(re.compile("^[Bb][Aa][Dd]\s*",re.UNICODE))
    spatialPrefixRegExes.append(re.compile("^[Ss][Aa][Nn][Kk][Tt][\s-]*",re.UNICODE))
    spatialPrefixRegExes.append(re.compile("^[Ss][Aa][Ii][Nn][Tt][\s-]*",re.UNICODE))
    spatialPrefixRegExes.append(re.compile("^[S][t]\.[\s-]*",re.UNICODE))
    spatialPrefixRegExes.append(re.compile("^[Dd][Ee][Nn]\s*",re.UNICODE))
    spatialPrefixRegExes.append(re.compile("^[Ne][Ee][Ww]\s*",re.UNICODE))

    #print "Tested string: >%s<" % testString
    
    if allowExactStringMatching:
        # checks whether the spatial is known to consist of more than one word
        # for the sake of efficiency we will only check for spatial names with the same leading character (see above)
        lowTestString=testString.lower()
        if len(lowTestString)>=1:
            currentLetter=lowTestString[0]
            if currentLetter in cityNGramsDE:
                for cityName in cityNGramsDE[currentLetter]:
                    foundIndex=lowTestString.find(cityName.lower())
                    #regexCity = re.compile("^\b"+cityName.lower()+"\b",re.UNICODE)
                    r=re.match("\\b"+cityName.lower()+"\\b",lowTestString)
                    #if foundIndex==0:
                    if r is not None:
                        #print "Compound city: "+cityName+" @ "+str(foundIndex)
                        return cityName
    
    # general purpose splitting
    foundSpatialPrefix=False
    for i,r in enumerate(spatialPrefixRegExes):
        m = r.search(testString)
        if m:
            #print "Prefix %i" %i
            foundSpatialPrefix=True
    #print type(testString)
    m = regex.split(testString)
    
    if foundSpatialPrefix:
        if len(m)>1:
            return m[0]+" "+m[1]
    else:
        return m[0]

print(pickFirstCity('Bad Königshofen im Grabfeld'))

# %% [markdown]
# bevor man die erste stadt auswählt muss man, sich die einträge mit mehr als einer stadt speichern.

# %%
counter=0
maxItems=df3.shape[0]

multipleCitiesPPN=dict()

printLog("Processing multiple spatial names entries...")
for row in df3.iterrows():
    ppn=str(row[1]["PPN"])  
    spatialC=str(row[1]["spatialClean"])
    multipleCitiesPPN[ppn]=[]
    
    counter=counter+1
    if counter%10000==0:
        printLog("\tProcessed %i items of %i"%(counter,maxItems))
                
    if spatialC:
        origSpatialClean="<"+spatialC+"> ("+ppn+")"
        f=pickFirstCity(spatialC)
        loopCount=1
        while f:
            #print f
            multipleCitiesPPN[ppn].append(f)
            #py27 spatialC=spatialC.decode("utf-8")
            spatialC=re.sub('\s+',' ',spatialC.replace(f,u"")).strip()
            #py27 spatialC=spatialC.encode("utf-8")
            if spatialC:
                #print "<"+f.encode("utf-8")+"> | <"+spatialC+">"
                #f=spatialC
                f=pickFirstCity(spatialC)
            else:
                #print origSpatialClean
                break
            loopCount=loopCount+1
            if loopCount>15:
                printLog("Max. loop count reached @ "+origSpatialClean+ " with last f of: <"+f+">")
                break
        #if f:
            #spatialC=spatialC.decode("utf-8")
            #spatialC=spatialC.replace(f,u"").strip()
            #spatialC=spatialC.encode("utf-8")
            #if spatialC:
                #print origSpatialClean
                #print "<"+f.encode("utf-8")+"> | <"+spatialC+">"
                #counter=counter+1
                #if counter==10:
                    #break
    #print ppn
    #break
printLog("Done.")
pickleCompress("./picklez/multipleSpatialNamesPerPPN.picklez",multipleCitiesPPN)

# %% [markdown]
# display the PPNs with multiple spatial names

# %%
for ppn in multipleCitiesPPN:
    array=multipleCitiesPPN[ppn]
    if len(array)>1:
        #py27 print(ppn+":\t"+"; ".join(array).encode("utf-8"))
        print(ppn+":\t"+"; ".join(array))
        #for e in array:
            #print e.encode("utf-8")

# %% [markdown]
# * interessante PPN: PPN780104447; PPN771083963; PPN792355296; PPN735012342
# * Umgang mit ? klären
# * Einträge des Arrays übeprüfen: Propositionen (auch Mehrwerte-Komposita wie "an der"), Nicht-Ortsnamen (z.B. Poststempel)

# %% [markdown]
# * finally, we can extract the first cities
#
# * next cell might take ca. 3 min. with list-based exact matching

# %%
printLog("Detecting and picking first cities...")
uniqueSpatials=df3["spatialClean"].unique()
beforeClusterClean=len(uniqueSpatials)
df3["spatialClean"]=df3["spatialClean"].apply(pickFirstCity)
printLog("Done.")

if allowExactStringMatching:
    pickleCompress("./picklez/df3_exactmatch_cities.picklez",df3)
else:
    df3=pickleDecompress("./picklez/df3_exactmatch_cities.picklez")
printLog("Done.")

# %%
df3[df3.coverage.notnull()].head(20)

# %% [markdown]
# gate 4
#
# check our results

# %%
uniqueSpatials=df3["spatialClean"].unique()
afterClusterClean=len(uniqueSpatials)
words=uniqueSpatials
#words
print("Before cluster cleaning: %i" % beforeClusterClean)
print("After cluster cleaning: %i" % afterClusterClean)

# %%
def d2(coord):
    #print "Altered d()"
    #print coord
    i, j = coord
    #print(str(type(words[i]))+" : "+str(type(words[j])))
    #py27 if not type(words[i])==unicode:
        #print "bumm "+ str(words[i])+" :"+str(i)
    if not words[i]:
        return 1.0
    #py27 if not type(words[j])==unicode:
        #print "bamm " + str(words[j])+" :"+str(j)
    if not words[j]:
        return 1.0
    dist=1 - jaro_distance(words[i],words[j]) # because jaro_distance is actually returning a similarity
    #print "%s vs. %s -> %f" %(words[i],words[j],dist)
    #return 1 - jaro_distance(unicode(str(words[i]), 'utf-8'), unicode(str(words[j]), 'utf-8'))
    return dist

def d3(coord):
    #print "Altered d()"
    #print coord
    i, j = coord
    #print str(type(words[i]))+" : "+str(type(words[j]))
    #py27 if not type(words[i])==unicode:
        #print "bumm "+ str(words[i])+" :"+str(i)
    if not words[i]:
        return 1.0
    #py27 if not type(words[j])==unicode:
        #print "bamm " + str(words[j])+" :"+str(j)
    if not words[j]:
        return 1.0
    dist=1 - jaro_winkler(words[i],words[j]) # because jaro_distance is actually returning a similarity
    #print "%s vs. %s -> %f" %(words[i],words[j],dist)
    return dist

# %% [markdown]
# vielleicht nötig, das ganze außerhalb des jupyter-notebooks auszuführen, wenn es time out probleme (siehe console) gibt

# %%
if not demoClustering:
    printLog("Calculating Jaro distances...")
    r=np.triu_indices(afterClusterClean, 1)
    r2=np.apply_along_axis(d2, 0, r)
    Z=scipycluster.linkage(r2)
    pickle.dump( Z, open( "cluster_hierarchy_linkage_result.pickle", "wb" ) )
    
    # Jaro-Winkler
    printLog("Calculating Jaro-Winkler distances...")
    r=np.triu_indices(afterClusterClean, 1)
    r3=np.apply_along_axis(d3, 0, r)
    Z3=scipycluster.linkage(r3)
    pickle.dump( Z3, open( "cluster_hierarchy_linkage_jw_result.pickle", "wb" ) )
    #pickle.dump( r2, open( "r2.pickle", "wb" ) )
    printLog("Distance matrices created. Done.")
    # (END_HERE_FOR_LINKAGE)

# %% [markdown]
# ### Working with the "Final" Data

# %%
## load stuff
printLog("Loading final data...")
# Jaro
#Z_huge=pickle.load( open( "cluster_hierarchy_linkage_result.pickle_bak", "rb" ) )
# Jaro-Winkler
Z_huge=pickle.load( open( "cluster_hierarchy_linkage_jw_result.pickle", "rb" ) )

#r2=pickle.load( open( "r2.pickle", "rb" ) )
printLog("Loading final data completed.")

# %% [markdown]
# group records by their cluster and display results

# %%
uniqueSpatials=df3["spatialClean"].unique()
words=uniqueSpatials
print(len(words))
# Jaro
#clusters=scipycluster.fcluster(Z_huge, t=0.115,criterion="distance") # je höher d, desto mehr kommt in 1 cluster
# Jaro-Winkler
clusters=scipycluster.fcluster(Z_huge, t=0.095,criterion="distance") # je höher d, desto mehr kommt in 1 cluster

print(clusters)
df3['spatialCluster'] = df3["spatialClean"].apply(getClusterID)
grp=df3.groupby("spatialCluster")

print("Number of clusters: %i" % len(grp.groups.keys()))

# save the clusters' names (for simplicity, we just take the name of the cluster's first element)
clusterNames=dict()
maxKey=-1
for key in grp.groups.keys():
    if key:
        if key>maxKey:
            maxKey=key
        if not key in clusterNames:
            clusterNames[key]=grp.get_group(key)["spatialClean"].unique()[0]
            
        print(str(key)+" <"+clusterNames[key]+"> contains:\n\t"+str(grp.get_group(key)["spatialClean"].unique()))
print("Max key value: %i"%maxKey)

# %%
grp.get_group(clusters[getWordIndex("Moskau")][0])["spatialClean"].unique()

# %%
grp.get_group(clusters[getWordIndex("Bamberg")][0])["spatialClean"].unique()

# %%
grp.get_group(clusters[getWordIndex("Berlin")][0])["spatialClean"].unique()

# %%
grp.get_group(clusters[getWordIndex("Frankfurt")][0])["spatialClean"].unique()

# %%
grp.get_group(clusters[getWordIndex("Hamburg")][0])["spatialClean"].unique()

# %%
grp.get_group(clusters[getWordIndex("Uri")][0])["spatialClean"].unique()

# %% [markdown]
# writing out the spatial cluster names...

# %%
def getClusterName(clusterID):
    if clusterID:
        if clusterID in clusterNames:
            r=clusterNames[clusterID]
            if r:
                return r.title()
        else:
            return np.nan
    else:
        return np.nan

df3['spatialClusterName'] = df3["spatialCluster"].apply(getClusterName)

# %% [markdown]
# manual corrections of the spatial cluster names (über Karte gesehen)
# * Carlsruhe
# * Crefeld
# * Weymar
# * Kjøbenhavn
# * Leipzig, Dresden
# * St. Peterburg
# * Coblentz
# * Halæ
#
# wäre besser, das vor dem Clustern zu tun
#
# it would be cumbersome to correct everything manually without further assistance as shown below

# %%
df3.ix[df3["spatialClusterName"]=="Carlsruhe", "spatialClusterName"] = "Karlsruhe"
df3.ix[df3["spatialClusterName"]=="Crefeld", "spatialClusterName"] = "Krefeld"
df3.ix[df3["spatialClusterName"]=="Weymar", "spatialClusterName"] = "Weimar"
df3.ix[df3["spatialClusterName"]==u"Kjøbenhavn", "spatialClusterName"] = u"København"
df3.ix[df3["spatialClusterName"]=="Leipzig, Dresden", "spatialClusterName"] = "Leipzig"
df3.ix[df3["spatialClusterName"]=="St. Peterburg", "spatialClusterName"] = "Sankt Petersburg"
df3.ix[df3["spatialClusterName"]=="Coblentz", "spatialClusterName"] = "Koblenz"
df3.ix[df3["spatialClusterName"]==u"Halæ", "spatialClusterName"] = u"Halle"

# %% [markdown]
# gate 5

# %%
# if there was no cluster name, just take the cleaned spatial name
df3.spatialClusterName.fillna(df3.spatialClean, inplace=True)
uniqueValues(df3)

# %% [markdown]
# * in the next step, we will extract all unique spatial cluster names for manual correction
# * an Excel sheet is created which also contains statistical data about the name in order to reveal outliers

# %%
dfValues={'SpatialClusterName':[],'Length':[],'NoOfElements':[],'Entries':[]}

sortedUniqueDF3=df3.sort_values(by="spatialClusterName")["spatialClusterName"].unique()

for uniqueName in sortedUniqueDF3:
    if uniqueName:
        length=str(len(uniqueName))
        entries=df3[df3["spatialClusterName"]==uniqueName]["spatialClean"].unique()
        noOfElements=str(len(entries))
        entriesString=",".join(entries)
        dfValues['SpatialClusterName'].append(uniqueName)
        dfValues['Length'].append(length)
        dfValues['NoOfElements'].append(noOfElements)
        dfValues['Entries'].append(entriesString)

spDF=pd.DataFrame(dfValues)
spDF = spDF[['SpatialClusterName', 'Length','NoOfElements','Entries']]
spDF['NoOfElements'] = pd.to_numeric(spDF['NoOfElements'])
spDF['Length'] = pd.to_numeric(spDF['Length'])
spDF['NewName']=""

stdLength=spDF.std()["Length"]
avgLength=spDF.mean()["Length"]
lowerLength=avgLength-stdLength
upperLength=avgLength+stdLength

stdNoOfElements=spDF.std()['NoOfElements']
avgNoOfElements=spDF.mean()['NoOfElements']
lowerNoOfElements=avgNoOfElements-stdNoOfElements
upperNoOfElements=avgNoOfElements+stdNoOfElements

def atypicalLength(x):
    if x < lowerLength or x > upperLength:
        return True
    else:
        return False

def atypicalNoOfElements(x):
    if x < lowerNoOfElements or x > upperNoOfElements:
        return True
    else:
        return False
    

spDF['AtypicalLength']=spDF['Length'].apply(atypicalLength)
spDF['AtypicalNoOfElements']=spDF['NoOfElements'].apply(atypicalNoOfElements)

spDF.to_excel("./spatialnames.xlsx",index=False)
spDF.shape

# %% [markdown]
# visualization of the results

# %%
grpNoOfElements=spDF.groupby("NoOfElements")
grpNoOfElements.count().plot()
if saveFiguresAsPDF:
    plt.savefig('./figures/noelements_cluster.pdf')

# %%
grpLength=spDF.groupby("Length")
grpLength.count().plot()
if saveFiguresAsPDF:
    plt.legend("")
    plt.ylabel("Amount")
    plt.xlabel("Length of Cluster Name")
    plt.savefig('./figures/length_spatialnames.pdf')

# %% [markdown]
# * "Poststempel", "Erscheinungsort", nicht entzifferbare Abkürzungen lassen sich so auffinden oder: St.Moritz Hotel, bzw. Kombinationen aus Verlagen und Orten; Signaturen/Referenzen: "Br117"; "VIII, 35"; (Budae,Budapest,Budapesten) wird als ein Cluster erkannt
#
# * Excel weißt statistische Besonderheiten aus und ist alphabetisch anhand der Cluster sortiert, so kommt man in gut XX Minuten mit der Korrektur durch
#
# * nicht alle Korrekturen sind manuell notwendig, da Ortsnamen auch Mehrsprachig in OSM oder GND(???) liegen
# * Character Encoding -Probleme sind dort auch gut zu erkennen (Piešťany)
#
# * consonant shift or sound changes
#
# * durch die Aufbereitung in ca. 45 Minuten leistbar (inkl. Recherchen in Historischen Ortsnamen, OSM und Google)
#
# Manual correction should be done in _spatialnamesCorrections.xlsx_. For illustration purposes, some correction have been made. Dots indicate rows for which the spatial name cluster will be removed.

# %%
spDF_manuallyCleaned=pd.read_excel("spatialnamesCorrections.xlsx")
spDF_manuallyCleaned.head(20)

# %%
df3[df3.spatialClusterName=="Aigen/Salzburg"].head() # returns PPN771101503 and/or PPN771101589

# %%
df3[df3.spatialClusterName=="1"].head() # returns PPN662043146 and PPN688520944

# %% [markdown]
# ## korrekturen einarbeiten; sagen, welche spalten wie ausgefüllt werden müssen; vorteil excel: leute kennen das tool und können sich alles anpassen, wie sie s brauchen

# %%
uniqueValues(df3)

# %%
# df3.ix[df3["spatialClusterName"]=="Carlsruhe", "spatialClusterName"] = "Karlsruhe"
printLog("Fixing spatial cluster names on the basis of manual corrections...")
counterRemoved=0
counterAltered=0
ignoredSpatialNamesLowerCase=[]

for row in spDF_manuallyCleaned.iterrows():
    #py27 newName=readDate=unicode(row[1]["NewName"])
    #py27 oldName=unicode(row[1]["SpatialClusterName"])
    newName=str(row[1]["NewName"])
    oldName=row[1]["SpatialClusterName"]
    
    if newName==".":
        #print("Removed: "+row[1]["SpatialClusterName"])
        df3.ix[df3["spatialClusterName"]==oldName, "spatialClusterName"] = ""
        ignoredSpatialNamesLowerCase.append(oldName.lower())
        counterRemoved=counterRemoved+1
    elif newName=="nan":
        pass
    else:
        #print("Changed: "+row[1]["SpatialClusterName"])
        df3.ix[df3["spatialClusterName"]==oldName, "spatialClusterName"] = newName
        counterAltered=counterAltered+1
        
printLog("Done.")
printLog("Removed clusters: %i"%counterRemoved)
printLog("Altered clusters: %i"%counterAltered)

# %% [markdown]
# gate 6

# %%
uniqueValues(df3)

# %% [markdown]
# # spatialCluster-ID muss auch noch angepasst werden und der spatialClusterName-Anzahl entsprechen

# %% [markdown]
# Some debugging...

# %%
df3[df3.PPN=="PPN771101503"].head()

# %%
df3[df3.PPN=="PPN662043146"].head()

# %%
pickleCompress('./picklez/clean_dataframe.picklez',df3)
pickleCompress('./picklez/ignoredSpatialNames.picklez',ignoredSpatialNamesLowerCase)

# %% [markdown]
# # Geodaten erzeugen

# %%
# uncomment only needed if you resume the notebook
df4=pickleDecompress('./picklez/clean_dataframe.picklez')
#ignoredSpatialNamesLowerCase=pickleDecompress('./picklez/ignoredSpatialNames.picklez')

# otherwise just run this line:
#df4=df3

# %%
# not tested with Python 3
if useGoogleMapsAPI:
    # idee ist, die Algorithmen von Google zu nutzen, um mit mitunter fehlerhaften, mehrsprachigen Ortsbezeichner umzugehen
    gmaps = googlemaps.Client(key=privateGoogleKey)
    # if you re-run this cell you might want to uncomment the following line
    latLng=dict()
    printLog("Fetching geolocations from Google Maps...")
    for row in df4.iterrows():
        if not row[1]["spatialClusterName"]:
            # in some cases, i.e., when the cluster was corrected manually above, 
            # we will ignore the spatialClean replacement
            loc=row[1]["spatialClean"]
            if loc:
                if not loc.lower() in ignoredSpatialNamesLowerCase:
                    printLog("Taking %s instead."%loc)
                else:
                    loc=None
        else:
            loc=row[1]["spatialClusterName"]
        if loc:
            if loc not in latLng:
                #printLog(loc)
                try:
                    retLL=gmaps.geocode(loc)
                    if len(retLL)>0:
                        latLng[loc]=retLL[0][u'geometry'][u'location']
                    else:
                        latLng[loc]=None
                except googlemaps.exceptions.ApiError:
                    printLog("Problem fetching: "+loc)
                    latLng[loc]=None
    printLog("Done.")

    triedAgain=[]
    printLog("Fetching geolocations from Google Maps a second time (aka the brute force failover solution)...")
    for row in df4.iterrows():
        if not row[1]["spatialClusterName"]:
            loc=row[1]["spatialClean"]
        else:
            loc=row[1]["spatialClusterName"]
        if loc:
            if latLng[loc]==None:
                if loc not in triedAgain:
                    #printLog(loc)
                    triedAgain.append(loc)
                    try:
                        retLL=gmaps.geocode(loc)
                        if len(retLL)>0:
                            latLng[loc]=retLL[0][u'geometry'][u'location']
                        else:
                            latLng[loc]=None
                    except googlemaps.exceptions.ApiError:
                        printLog("Problem fetching: "+loc)
                        latLng[loc]=None
    printLog("Done.")
    pickleCompress('./picklez/geo_coordinates.picklez',latLng)
else:
    printLog("Skipping Google Map API calls.")

# %% [markdown]
# alternative with OpenStreetMap http://wiki.openstreetmap.org/wiki/Nominatim#Reverse_Geocoding

# %%
if not useGoogleMapsAPI:
    if getSpatialNamesFromOSM:
        osmNominatimURL="http://nominatim.openstreetmap.org/search?format=json&namedetails=1&q="
        # if you re-run this cell you might want to uncomment the following line
        latLng=dict()
        names=dict()
    
        maxItems=df4.shape[0]
        counter=0
    
        printLog("Fetching geolocations from OpenStreetMaps...")
        for row in df4.iterrows():
            counter=counter+1
            if counter%5000==0:
                printLog("\tProcessed %i items of %i"%(counter,maxItems))
            if not row[1]["spatialClusterName"]:
                # in some cases, i.e., when the cluster was corrected manually above, 
                # we will ignore the spatialClean replacement
                loc=str(row[1]["spatialClean"])
                if loc:
                    if not loc.lower() in ignoredSpatialNamesLowerCase:
                        printLog("No spatial cluster name for %s. Taking %s instead."%(row[1]["PPN"],loc))
                    else:
                        loc=None
            else:
                loc=str(row[1]["spatialClusterName"])
            if loc:
                if loc not in latLng:
                #printLog(loc)
                    locURL=osmNominatimURL+urllib.parse.quote(loc).replace(" ","+")
                    try:
                        data = json.load(urllib.request.urlopen(locURL))
                        latLng[loc]=dict()
                        if len(data)>0:
                            #print data[0]
                            latLng[loc][u'lat']=data[0]["lat"]
                            latLng[loc][u'lng']=data[0]["lon"]
                            #print loc
                            names[loc]=dict()
                            if len(data[0]['namedetails'])>0:
                                for k,v in data[0]['namedetails'].items():
                                    names[loc][k]=v
                            else:
                                names[loc][u'name']=loc
                                #print "No namedetails for "+loc
                            #print names[loc]
                        else:
                            latLng[loc]=None
                    except IOError:
                        printLog("\tCould not open: "+locURL)
                        pickleCompress('./picklez/save_names.picklez',names)
                        pickleCompress('./picklez/save_latLng.picklez',latLng)
                    time.sleep(1) # see http://wiki.openstreetmap.org/wiki/Nominatim_usage_policy
        printLog("Number of coordinates: %i"%len(latLng))
        printLog("Done.")
    else:
        printLog("Skipping OpenStreetMap API calls.")
else:
    printLog("Skipping OpenStreetMap API calls.")

# %%
# for manual additions, you can directly pass an URL as the example below shows
#manualLocation="Kehl"
#data = json.load(urllib.urlopen("http://nominatim.openstreetmap.org/search?format=json&namedetails=1&q="+manualLocation))
#loc=manualLocation
#if len(data)>0:
#    latLng[loc][u'lat']=data[0]["lat"]
#    latLng[loc][u'lng']=data[0]["lon"]
#    names[loc]=dict()
#    if len(data[0]['namedetails'])>0:
#        for k,v in data[0]['namedetails'].items():
#            names[loc][k]=v
#    else:
#        names[loc][u'name']=loc
#else:
#    latLng[loc]=None

# %%
# save everything
if not useGoogleMapsAPI:
    if getSpatialNamesFromOSM:
        pickleCompress('./picklez/osm_names.picklez',names)
        pickleCompress('./picklez/osm_latLng.picklez',latLng)

# %%
if useGoogleMapsAPI:
    latLng=pickleDecompress('./picklez/geo_coordinates.picklez')
else:
    latLng=pickleDecompress('./picklez/osm_latLng.picklez')
    osmNames=pickleDecompress('./picklez/osm_names.picklez')

# %% [markdown]
# latitude und longitude aus den spatial names generieren

# %%
def getLat(spatialName):
    if spatialName:
        if spatialName in latLng:
            if latLng[spatialName]:
                return latLng[spatialName][u'lat']
            else:
                return np.nan
    else:
        return np.nan

def getLng(spatialName):
    if spatialName:
        if spatialName in latLng:
            if latLng[spatialName]:
                return latLng[spatialName][u'lng']
            else:
                return np.nan
    else:
        return np.nan

df4['latitude']=df4['spatialClusterName'].apply(getLat)
df4['longitude']=df4['spatialClusterName'].apply(getLng)

# %% [markdown]
# ### lambda-Ausdruck ansprechen (Church aus theoretischer Informatik...)

# %%
# overwrite every "nulled" column (i.e. NULL or NaN) with -1
df4.ix[df4["dateClean"].isnull(), "dateClean"] = -1
df4.ix[df4["dateClean"]=='nan', "dateClean"] = -1

df4["century"]=df4["dateClean"].apply(lambda x: int(int(x)/100)) # uns interessiert nur das jahrhundert
df4.head(20)

# %%
grpCentury=df4.groupby("century")
grpCentury.describe()

# %%
ax=grpCentury.count().plot()
ax.legend(bbox_to_anchor=(1.1, 1.05))

# %% [markdown]
# ### Text-based Clustering

# %%
printLog("Number of unique title fields %i"%len(df4.title.unique()))

# %%
#title soll geclustert werden -> textCluster
corpus=df4.title.astype(str)

# %% [markdown]
# The next cell will take a while to compute depending on your computer and the size of the corpus. To give an example, the following performance could be observed on a MacBook Pro (13-inch, 2018, Four Thunderbolt 3 Ports, 2,7 GHz Intel Core i7, 16 GB RAM):
# ```
# [2019-02-25 11:08:53.568526]	Clustering text with cluster target size 5000
# [2019-02-25 11:08:53.569143]		 Preparing tf*idf model
# [2019-02-25 11:08:56.634801]		 Number of feature names: 125000
# [2019-02-25 11:08:56.635519]		 K-Means clustering
# [2019-02-25 11:17:49.427231]	Done.
# ```

# %%
# in Python 3 you cannot save files over 4 GB, hence we have to run the clustering everytime  :-/
true_k=5000

if sys.version_info.major>=3 or allowComputationallyExpensiveCalculations:
    printLog("Clustering text with cluster target size %i"%true_k)
    printLog("\t Preparing tf*idf model")
    # from an analysis we know that there are 167,715 different words in the corpus
    # to speed up processing, we limit the vocabulary size to the ca. top-75% of the words
    tfidfvectorizer = TfidfVectorizer(min_df=1,max_features=125000) #max_features is used to limit the vocabulary size 
    Xtfidf=tfidfvectorizer.fit_transform(corpus)
    featNames=tfidfvectorizer.get_feature_names()
    printLog("\t Number of feature names: %i"%len(featNames))

    printLog("\t K-Means clustering")
    km=MiniBatchKMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
    # fit the k-means algorithm on the data created above
    km.fit(Xtfidf)
    if sys.version_info.major<3:
        pickleCompress('./picklez/textClustersK_'+str(true_k)+'.picklez',km)
else:
    km=pickleDecompress('./picklez/textClustersK_'+str(true_k)+'.picklez')
    printLog("\t Updating Dataframe")
# add the detected clusters as a new column to the original data frame
df4['textCluster']=km.labels_
printLog("Done.")

# %%
if allowComputationallyExpensiveCalculations:
    # group the data by the cluster and describe it
    df4.groupby('textCluster').describe()

# %%
df4=df4.sort_values(by="textCluster")
df4[['PPN','title','textCluster']].tail()

# %% [markdown]
# do the same with the creator column

# %%
#creator soll geclustert werden -> creatorCluster
corpus=df4.creator.astype(str)

# %%
printLog("Number of unique creator fields %i"%len(df4.creator.unique()))

# %% [markdown]
# ```
# [2019-02-25 11:18:40.288281]	Clustering text with cluster target size 20000
# [2019-02-25 11:18:40.289133]		 Preparing tf*idf model
# [2019-02-25 11:18:40.958502]		 Number of feature names: 26575
# [2019-02-25 11:18:40.959311]		 K-Means clustering
# [2019-02-25 11:26:49.960392]	Done.
# ```

# %%
true_k=20000

if sys.version_info.major>=3 or allowComputationallyExpensiveCalculations:
    printLog("Clustering text with cluster target size %i"%true_k)
    printLog("\t Preparing tf*idf model")
    tfidfvectorizer = TfidfVectorizer(min_df=1) #max_features setzen?
    Xtfidf=tfidfvectorizer.fit_transform(corpus)
    featNames=tfidfvectorizer.get_feature_names()
    printLog("\t Number of feature names: %i"%len(featNames))

    printLog("\t K-Means clustering")
    km=MiniBatchKMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
    # fit the k-means algorithm on the data created above
    km.fit(Xtfidf)
    if sys.version_info.major<3:
        pickleCompress('./picklez/creatorClustersK_'+str(true_k)+'.picklez',km)
else:
    km=pickleDecompress('./picklez/creatorClustersK_'+str(true_k)+'.picklez')

printLog("Done.")

# %%
# add the detected clusters as a new column to the original data frame
printLog("\t Updating Dataframe")
df4['creatorCluster']=km.labels_

df4=df4.sort_values(by="creatorCluster")
df4[['PPN','creator','creatorCluster']].tail()

# %%
imageBasePath="/Users/david/src/__datasets/"
def getImageAvailability(ppn):
    if ppn:
        if os.path.exists(imageBasePath+"firstpages/"+ppn+".jpg"):
            return "firstpages/"+ppn+".jpg"
        else:
            if os.path.exists(imageBasePath+"titlepages/"+ppn+".jpg"):
                return "titlepages/"+ppn+".jpg"
            else:
                return None
    else:
        return None

printLog("Checking image availability...")
df4['titleImage']=df4['PPN'].apply(getImageAvailability)

recordsWithTitleImage=df4[df4.titleImage.notnull()].shape[0]
recordsWithoutTitleImage=df4[df4.titleImage.isnull()].shape[0]
printLog("Records with title image: %i\twithout title image (multi-volumes): %i"%(recordsWithTitleImage,recordsWithoutTitleImage))
printLog("Done.")

# %%
pickleCompress('./picklez/clean_dataframe_with_century.picklez',df4)

# %%
df4.to_csv("cleanedData.csv",sep=';',header=True, index=False, encoding='utf-8')
df4.to_excel("cleanedData.xlsx",header=True, index=False)

# %% [markdown]
# ## The Analyses Shall Begin!
# safe to continue from here if you resume the notebook...

# %%
# if you have run this notebook from top to bottom, you don't have to reload the data
df4=pickleDecompress('./picklez/clean_dataframe_with_century.picklez')
grpCentury=df4.groupby("century")
#df4.shape

# %%
uniqueValues(df4)

# %% [markdown]
# ### Speeding things up
#
# dauert ca.40 min mit Zugriff innerhalb der Schleife mittels df4[df4.PPN==ppn].iloc[-1]['title'], deshalb look-up, so dauert alles komplett ca. 40 Sekunden.

# %%
printLog("Creating PPN look-up table of %i unique PPNs."%len(df4.PPN.unique()))
ppnLookup=dict()
for row in df4.iterrows():
    ppn=readDate=str(row[1]["PPN"])
    if ppn not in ppnLookup:
        ppnLookup[ppn]=dict()
    # it is redundant but handy for later JSON exports to save the PPN as a value as well
    ppnLookup[ppn]["ppn"]=ppn
    ppnLookup[ppn]["dateClean"]=str(row[1]["dateClean"])
    ppnLookup[ppn]["title"]=str(row[1]["title"])
    ppnLookup[ppn]["creator"]=str(row[1]["creator"])
    
    if not row[1]["spatialClusterName"]:
        if row[1]["spatialClean"]:
            ppnLookup[ppn]["spatialClusterName"]=row[1]["spatialClean"]
        else:
            ppnLookup[ppn]["spatialClusterName"]="None"
    else:
        ppnLookup[ppn]["spatialClusterName"]=row[1]["spatialClusterName"] 
    ppnLookup[ppn]['spatialClean']=row[1]["spatialClean"]
    ppnLookup[ppn]['spatialRaw']=str(row[1]["coverage"])
    ppnLookup[ppn]['mediatype']=str(row[1]["type"])
    ppnLookup[ppn]['subject']=str(row[1]["subject"])
    # daz
    #ppnLookup[ppn]['source']=str(row[1]["source"])
    ppnLookup[ppn]['publisher']=str(row[1]["publisher"])
    #ppnLookup[ppn]['alternative']=str(row[1]["alternative"])
    ppnLookup[ppn]['lat']=str(row[1]["latitude"])
    ppnLookup[ppn]['lng']=str(row[1]["longitude"])
    ppnLookup[ppn]['textCluster']=str(row[1]["textCluster"])
    ppnLookup[ppn]['creatorCluster']=str(row[1]["creatorCluster"])
    ppnLookup[ppn]['titleImage']=str(row[1]["titleImage"])
    
pickleCompress("./picklez/ppnLookup.picklez",ppnLookup)
printLog("Done.")

# %%
#serialize data per PPN; one large file would be more than 80 MB and thus too much for a transmission to a browser
if serializePPNLookup2JSON:
    printLog("Serializing PPN lookup table to JSON in directory:\n\t"+jsonWebDir)
    for k in ppnLookup:
        dump=json.dumps(ppnLookup[k])

        jsonFile = open(jsonWebDir+k+".json", "w")
        jsonFile.write(dump)
        jsonFile.close()
    printLog("Done.")

# %% [markdown]
# ### A Creation and Its Place of Origin - Graphing the Library World
# build a network graph: do publishers and their publication locations resemble superheroes?
# verbindung publisher/creator - spatialClusterName; dazu: dateClean, century, title

# %%
def createGraph(consideredDataFrame):
    # for testing purposes it is handy to limit the number of records
    #consideredDataFrame=consideredDataFrame[(consideredDataFrame.Year>=1961) & (consideredDataFrame.Year<1975)]

    # create an empty graph from the nx (networkx) package imported above
    G=nx.Graph()

    rowCount=0
    seenCreators=[]
    seenLocations=[]
    for row in consideredDataFrame.iterrows():
        rowCount=rowCount+1
        #if rowCount%1000==0:
        #    printLog("Processed %i rows..."%rowCount)
        ppn=row[1]["PPN"]
        creator=str(row[1]["publisher"]).upper()
        if creator=="NAN":
            creator=str(row[1]["creator"]).upper()
        if creator=="NAN":
            creator="Unknown creator"
        
        location=row[1]["spatialClusterName"]
        if location=="NAN":
            location="s. l."
        elif not location:
            location="s. l."
        year=row[1]["dateClean"]
        subject=row[1]["subject"]
        
        #if not creator in G.nodes():
        #if not creator in seenCreators:
        
        G.add_node(creator)
        if not creator=="Unknown creator":
            # the name attribute will be helpful for D3.js visualizations
            G.node[creator]['name'] = creator
            G.node[creator]['year'] = year
            G.node[creator]['type'] = "creator"
            G.node[creator]['subject']=subject
            G.node[creator]['century']=row[1]["century"]
            seenCreators.append(creator)
        else:
            G.node[creator]['name'] = creator
            G.node[creator]['year'] = year
            G.node[creator]['type'] = "no_creator"
        
        #if not location in G.nodes():
        #if not location in seenLocations:
       
        # the name attribute will be helpful for D3.js visualizations
        if not location=="s. l.":
            G.add_node(location)
            G.node[location]['name'] = location
            G.node[location]['year'] = year
            G.node[location]['type'] = "location"
            seenLocations.append(location)
            G.add_edge(creator,location)
        else:
            pass
        # if we would like to add the unknown location, uncomment the following lines and the comment the last line
            #G.add_node(location)
            #G.node[location]['name'] = location
            #G.node[location]['year'] = year
            #G.node[location]['type'] = "no_location"
    
        #print location
        #print creator
        #print "* * *"
    return G

# %%
printLog("Creating graphs and additional data...")

graphsPerCentury=dict()
ppnPerCentury=OrderedDict()
for century in range(7,21): # we know that there are only media from the 7th century on
    if century in grpCentury.groups:
        centDF=grpCentury.get_group(century)
        returnedGraph=createGraph(centDF)
        graphsPerCentury[century]=returnedGraph
        printLog("Graph for century %i built with %i nodes and %i edges."%(century, len(returnedGraph.nodes()),len(returnedGraph.edges())))
        # export as GraphML, which can be read by Gephi
        nx.write_gml(returnedGraph,"graphs/century_"+str(century)+".gml")
        
        # now save the PPNs
        ppnPerCentury[century]=[]
        for row in centDF.iterrows():
            ppn=row[1]["PPN"]
            ppnPerCentury[century].append(ppn)

# create the full graph
returnedGraph=createGraph(df4)
printLog("Graph for all centuries built with %i nodes and %i edges."%(len(returnedGraph.nodes()),len(returnedGraph.edges())))
nx.write_gml(returnedGraph,"graphs/all_centuries.gml")
printLog("Done.")

# %%
def createFullGraph(consideredDataFrame):
    # for testing purposes it is handy to limit the number of records
    #consideredDataFrame=consideredDataFrame[(consideredDataFrame.Year>=1961) & (consideredDataFrame.Year<1975)]

    # create an empty graph from the nx (networkx) package imported above
    G=nx.Graph()

    rowCount=0
    seenCreators=[]
    seenLocations=[]
    for row in consideredDataFrame.iterrows():
        rowCount=rowCount+1
        #if rowCount%1000==0:
        #    printLog("Processed %i rows..."%rowCount)
        ppn=row[1]["PPN"]
        creator=str(row[1]["publisher"]).upper()
        if creator=="NAN":
            creator=str(row[1]["creator"]).upper()
        if creator=="NAN":
            creator="Unknown creator"
        
        location=row[1]["spatialClusterName"]
        if location=="NAN":
            location="s. l."
        elif not location:
            location="s. l."
        year=row[1]["dateClean"]
        subject=row[1]["subject"]
        
        #if not creator in G.nodes():
        #if not creator in seenCreators:
        
        G.add_node(creator)
        if not creator=="Unknown creator":
            # the name attribute will be helpful for D3.js visualizations
            G.node[creator]['name'] = creator
            G.node[creator]['year'] = year
            G.node[creator]['type'] = "creator"
            G.node[creator]['subject']=subject
            G.node[creator]['century']=row[1]["century"]
            seenCreators.append(creator)
        else:
            G.node[creator]['name'] = creator
            G.node[creator]['year'] = year
            G.node[creator]['type'] = "no_creator"
        
        #if not location in G.nodes():
        #if not location in seenLocations:
       
        # the name attribute will be helpful for D3.js visualizations
        if not location=="s. l.":
            G.add_node(location)
            G.node[location]['name'] = location
            G.node[location]['year'] = year
            G.node[location]['type'] = "location"
            seenLocations.append(location)
            G.add_edge(creator,location)
        else:
            pass
        # if we would like to add the unknown location, uncomment the following lines and the comment the last line
            #G.add_node(location)
            #G.node[location]['name'] = location
            #G.node[location]['year'] = year
            #G.node[location]['type'] = "no_location"
    
        #print location
        #print creator
        #print "* * *"
        
        G.add_node(ppn)
        G.node[ppn]['name'] = str(ppn)
        G.node[ppn]['year'] = year
        G.node[ppn]['type'] = "PPN"
        G.node[ppn]['century']=row[1]["century"]
        G.add_edge(ppn,creator)

    return G

# %%
printLog("Creating graphs incl. PPNs...")

graphsPerCentury=dict()
for century in range(7,21): # we know that there are only media from the 7th century on
    if century in grpCentury.groups:
        centDF=grpCentury.get_group(century)
        returnedGraph=createFullGraph(centDF)
        graphsPerCentury[century]=returnedGraph
        gmlPath="graphs/century_ppn_"+str(century)+".gml"
        # export as GraphML, which can be read by Gephi
        nx.write_gml(returnedGraph,gmlPath)
        printLog("Graph for century %i built with %i nodes and %i edges (see %s)."%(century, len(returnedGraph.nodes()),len(returnedGraph.edges()),gmlPath))
        

# create the full graph
returnedGraph=createFullGraph(df4)
gmlPath="graphs/all_centuries_ppn.gml"
nx.write_gml(returnedGraph,gmlPath)
printLog("Graph for all centuries built with %i nodes and %i edges (see %s)."%(len(returnedGraph.nodes()),len(returnedGraph.edges()),gmlPath))
printLog("Done.")

# %%
# takes ca. 45 min for a graph built with 16368 nodes and 18539 edges on my MacBook Pro, i.e., with the full data set
# with http://networkx.github.io/documentation/latest/reference/generated/networkx.drawing.layout.spring_layout.html#networkx.drawing.layout.spring_layout
# theory behind it: https://en.wikipedia.org/wiki/Force-directed_graph_drawing
#printLog("Preparing to draw...")

#nx.draw(G)
#plt.savefig("graph.pdf")
#printLog("Done.")

# %% [markdown]
# generic graph building

# %%
def createGenericGraph(consideredDataFrame):
    # for testing purposes it is handy to limit the number of records
    #consideredDataFrame=consideredDataFrame[(consideredDataFrame.Year>=1961) & (consideredDataFrame.Year<1975)]

    # create an empty graph from the nx (networkx) package imported above
    G=nx.Graph()

    rowCount=0
    seenCreators=[]
    seenLocations=[]
    # [u'PPN', u'alternative', u'creator', u'dataProvider', u'date', 
    # u'description', u'format', u'identifier', u'isShownAt', u'issued', 
    # u'object', u'provider', u'publisher', u'relation', u'rights', u'source', 
    # u'spatial', u'subject', u'title', u'type', u'spatialClean', u'dateClean', 
    # u'spatialCluster', u'spatialClusterName', u'latitude', u'longitude', u'century']
    ignoreList=[u'rights', u'issued',u'source',u'spatial',u'dataProvider', u'date',u'format',u'spatialCluster',u'century', u'provider']
    for row in consideredDataFrame.iterrows():#itertuples(): 
        ppn=val=row[1]["PPN"]
        G.add_node(ppn)
        G.node[ppn]['name'] = ppn
        G.node[ppn]['type'] = "PPN"
            
        keys=row[1].keys()
        for k in keys:
            elementEmpty=False
            if k not in ignoreList:
                #print k
                val=row[1][k]
                if val: 
                    if type(val) is float:
                        if not math.isnan(val):
                            #print row[1][k]
                            pass
                        else:
                            #print "I DON'T KNOW!"
                            elementEmpty=True
                    else:
                        #print row[1][k]
                        pass
                else:
                    #print "I DON'T KNOW!"
                    elementEmpty=True
                
                # only process non-empty elements
                if not elementEmpty:
                    if not val in G.nodes():
                        G.add_node(val)
                        G.node[val]['name'] = val
                        G.node[val]['type'] = k
                    
                    G.add_edge(ppn,val)
            
        # spatialClean auf spatialClusterName binden, den rest dann mit spatialClusterName
        # spatialClusterName erhält als Attribut latitude/longitude

       

    return G

# %%
if allowComputationallyExpensiveCalculations:
    saveDir="./graphs/generics/"
    if not os.path.exists(saveDir):
        os.makedirs(saveDir)
        
    printLog("Creating graphs incl. PPNs...")

    graphsPerCentury=dict()
    for century in range(7,21):#(7,21): # we know that there are only media from the 7th century on
        if century in grpCentury.groups:
            centDF=grpCentury.get_group(century)
            returnedGraph=createGenericGraph(centDF)
            graphsPerCentury[century]=returnedGraph
            gmlPath="graphs/generics/full_"+str(century)+".gml"
            # export as GraphML, which can be read by Gephi
            nx.write_gml(returnedGraph,gmlPath)
            printLog("Graph for century %i built with %i nodes and %i edges (see %s)."%(century, len(returnedGraph.nodes()),len(returnedGraph.edges()),gmlPath))
    printLog("Done.")

# %% [markdown]
# # TO DO
# Graph mit allen Städten und PPNs eines Spatial Clusters

# %% [markdown]
# xxx

# %%
grpCentury.get_group(17).count()

# %% [markdown]
# ### Exploring the Collection by Visual Content
# * reading the feature files takes approx. 12 min
# * erklären, woher die CBIR features kommen (https://en.wikipedia.org/wiki/Bag-of-words_model_in_computer_vision)
#
# ![Visual Words](img/visword.jpg)
# By Masterwaw - Own work, CC BY-SA 3.0, https://commons.wikimedia.org/w/index.php?curid=19645418
#
# Scale-invariant feature transform, reference for local feature detection
#
# ![Visual Word Generation](img/visword_generation2.png)
#
# int sampleDocumentsToCreateCodebook = 5000;
# int numberOfClusters = 1000;
#
# next step takes ca. 40 minutes if the raw features are loaded from disk and converted

# %%
featureBaseDir="./featureFiles.5k1k/"
missingPPNs=[]
readPPNs=[]
featuresPPN=[]
featsPerCentury=dict()
readPpnPerCentury=dict()

printLog("Loading features...")
if reinterpretVisualWordRawFeatures:
    for century in range(7,21):
        if century in grpCentury.groups:
            featsPerCentury[century]=[]
    for century in range(7,21):
        if century in grpCentury.groups:
            readPpnPerCentury[century]=[]

    index=0
    for row in df4.iterrows():
        index=index+1
        if index%10000==0:
            printLog("Processed %i documents."%index)
        ppn=str(row[1]["PPN"])
        if os.path.isfile(featureBaseDir+ppn+".csv"):
            #print ppn+" okay."
            featFile=open(featureBaseDir+ppn+".csv")
            for line in featFile:
                feature=line
            tokens=feature.split()
            harray=[]
            for t in tokens:
                harray.append(int(t,16))
            featFile.close()

            readPPNs.append(ppn)
            featuresPPN.append(np.array(harray,dtype=np.uint8))
            # check to which century the feature belongs
            for century in range(7,21):
                if century in grpCentury.groups:
                    if ppn in ppnPerCentury[century]:
                        readPpnPerCentury[century].append(ppn)
                        featsPerCentury[century].append(np.array(harray,dtype=np.uint8))
        else:
            missingPPNs.append(ppn)
    printLog("Done.")
    printLog("Number of missing PPNs: %i"%len(missingPPNs))
    
    # pickling takes about 15 minutes
    pickleCompress('./picklez/missingPPNs.picklez',missingPPNs)
    pickleCompress('./picklez/readPPNs.picklez',readPPNs)
    pickleCompress('./picklez/featuresPPN.picklez',featuresPPN)
    pickleCompress('./picklez/featsPerCentury.picklez',featsPerCentury)
    pickleCompress('./picklez/readPpnPerCentury.picklez',readPpnPerCentury)
    printLog("Pickling completed.")
else:
    # takes about 1 minute
    missingPPNs=pickleDecompress('./picklez/missingPPNs.picklez')
    readPPNs=pickleDecompress('./picklez/readPPNs.picklez')
    featuresPPN=pickleDecompress('./picklez/featuresPPN.picklez')
    featsPerCentury=pickleDecompress('./picklez/featsPerCentury.picklez')
    readPpnPerCentury=pickleDecompress('./picklez/readPpnPerCentury.picklez')
    printLog("Loading from disk completed.")

# %% [markdown]
# * Clustering of 101031 elements started with 1000 as cluster target size: 3 min
# * note that the cluster labels vary for each run

# %%
# working with all features will most likely halt your computer because of the memory consumption if you use KMeans!
feats=featuresPPN#[:20000] 

# define the number of clusters to be found
true_k=1000
printLog("Clustering of %i elements started with %i as cluster target size."%(len(feats),true_k))
# initialize the k-means algorithm
#km = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
# we will rely on the mini batch k-means algorithm due to performance consideration otherwise your computer might crash...
km = MiniBatchKMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)

# apply the algorithm on the data
km.fit(feats)
printLog("Clustering finished.")
km.labels_

# %%
saveDir="./html/_clusteroverview_allcents/"
if not os.path.exists(saveDir):
        os.makedirs(saveDir)
        
imgDir="../../web/thumbnails/"
#imgDir="file:///Volumes/2TB_WD/sbb_images/tmp/"
htmlHead="<html><head></head><body bgcolor='#000000'>"
htmlTail="</body></html>"
clusters=dict()
for i,val in enumerate(km.labels_):
    if val not in clusters:
        clusters[val]=[]
    clusters[val].append(readPPNs[i])
#print clusters
for i in clusters:
    htmlOut=open(saveDir+str(i)+".html","w")
    htmlOut.write(htmlHead+"\n")
    htmlOut.write("<a href='"+str(i-1)+".html'>last</a> &nbsp;"+"<a href='"+str(i+1)+".html'>next</a>\n"+"<br />")
    for ppn in clusters[i]:
        htmlOut.write("<img width='170' src='"+imgDir+ppn+".jpg' />\n")
    htmlOut.write(htmlTail)
    htmlOut.close()

# %% [markdown]
# repeat the same step for each century...

# %%
clustersPerCentury=dict()
maxClusterAmount=100
printLog("Starting clustering per century...")
for century in featsPerCentury:
    maxClusters=len(featsPerCentury[century])
    # define the number of clusters to be found
    true_k=int(maxClusters*0.1+1)
    # restrict the number of clusters to prevent extremely large clusters
    if true_k>(maxClusterAmount*2):
        true_k=maxClusterAmount+int(maxClusters*0.005)
    elif true_k>maxClusterAmount:
        true_k=maxClusterAmount+int(maxClusters*0.01)
    printLog("Clustering of %i element(s) started with %i as cluster target size for century %i."%(maxClusters,true_k,century))
    # initialize the k-means algorithm
    #km = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
    # we will rely on the mini batch k-means algorithm due to performance consideration otherwise your computer might crash...
    km = MiniBatchKMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)

    # apply the algorithm on the data
    km.fit(featsPerCentury[century])
    clustersPerCentury[century]=km.labels_
printLog("Clustering finished.")

# %% [markdown]
# Computing 'centroids' takes up to 6 minutes;

# %%
clusterCentroidsPerCentury=dict()
numberCentroids=0

printLog("Computing 'centroids' for...")

for century in clustersPerCentury:
    printLog("\tcentury %i"%century)
    clusters=dict()
    centFeats=dict()

    for i,val in enumerate(clustersPerCentury[century]):
        if val not in centFeats:
            centFeats[val]=[]
        if val not in clusters:
            clusters[val]=[]
        index=readPPNs.index(readPpnPerCentury[century][i])
        clusters[val].append(readPpnPerCentury[century][i])
        centFeats[val].append(featuresPPN[index])

    clusterCentroidsPerCentury[century]=dict()
    for cluster in centFeats:
        r=centFeats[cluster]
        meanDistances=[]
        D=pairwise_distances(r,r)
        #A distance matrix D such that D_{i, j} is the distance between the ith and jth vectors of the given matrix X, if Y is None.
        #If Y is not None, then D_{i, j} is the distance between the ith array from X and the jth array from Y.
        # distance between element 0 and 13 (=0.0 if X and Y are anti-correlated)
        #D[0][13]
        for row in D:
            # each row in D stands for one document and its distances to all other documents
            # by calculating its mean, we compute how dissimilar this document is to all others
            meanDistances.append(np.mean(row))
        #print meanDistances
        minVal=np.min(meanDistances)
        index=meanDistances.index(minVal)
        clusterCentroidsPerCentury[century][cluster]=clusters[cluster][index]
        numberCentroids=numberCentroids+1
        #print str(cluster)+": "+str(clusters[cluster][index])+" (of %i elements)"%len(meanDistances)

printLog("Done computing %i 'centroids'."%numberCentroids)

# %% [markdown]
# * iterate over all centuries and save output per centroids
# * CSV output is for the visualization with the web-based QA tools

# %%
saveDir="./html/_clusteroverview_per_century/"
if not os.path.exists(saveDir):
        os.makedirs(saveDir)
        
printLog("Creating HTML and CSV output...")

# limits the shown PPNs per century-separated cluster
limitClusterCentroidsPerCentury=10
# for the cluster detail views limitClusterCentroidsPerCentury*centuryLimitFactor elements will be displayed per centroid
centuryLimitFactor=3

csvOut=open("./web/data/clusters.csv","w")
csvOut.write("id,value\n")
rootNode="all."
csvOut.write("all,"+"\n")

for century in clustersPerCentury:
    largestClusterSize=0
    largestCluster=None
    
    csvCenturyOut=open("./web/data/"+str(century)+".csv","w")
    csvCenturyOut.write("id,value\n")
    rootCenturyNode="all"
    csvCenturyOut.write(rootCenturyNode+","+"\n")
    
    csvOut.write("all."+str(century)+","+"\n")
    
    saveDir="./html/_clusteroverview_per_century/"+str(century)+"/"
    if not os.path.exists(saveDir):
        os.makedirs(saveDir)
    imgDir="../../../web/thumbnails/"
    #imgDir="file:///Volumes/2TB_WD/sbb_images/tmp/"
    htmlHead="<html><head></head><body bgcolor='#000000'>"
    htmlTail="</body></html>"
    
    clusters=dict()
    for i,val in enumerate(clustersPerCentury[century]):
        if val not in clusters:
            clusters[val]=[]
        clusters[val].append(readPpnPerCentury[century][i])
        

    clusterSizes=[]
    shownCentroidCount=0
    shownMoreCentroidsAvailable=False
    
    noClustersInCentury=len(clusters)
    for i in clusters:
        clusterSizes.append(len(clusters[i]))
        
        if largestClusterSize<len(clusters[i]):
            largestClusterSize=len(clusters[i])
            largestCluster=i
        
        # the cluster's centroid
        # 14/14: PPN789774356
        #<br/>
        #<img src='file:///Users/david/Documents/src/python/CulturalAnalytics/tmp/PPN789774356.jpg' />
        #print "\tCentroid for cluster "+str(i)+": "+str(clusterCentroidsPerCentury[century][i])
        centroid="<img src='"+imgDir+str(clusterCentroidsPerCentury[century][i])+".jpg' />\n"+"<br/>\n"
    
        if shownCentroidCount<limitClusterCentroidsPerCentury:
            shownCentroidCount=shownCentroidCount+1
            csvOut.write(rootNode+str(century)+"."+str(clusterCentroidsPerCentury[century][i])+",\n")
        else:
            if not shownMoreCentroidsAvailable:
                csvOut.write(rootNode+str(century)+".more,\n")
                shownMoreCentroidsAvailable=True
                
        csvCenturyOut.write(rootCenturyNode+"."+str(clusterCentroidsPerCentury[century][i])+",\n")
        
        
        
        htmlOut=open(saveDir+str(i)+".html","w")
        htmlOut.write(htmlHead+"\n")
        #htmlOut.write("<a href='"+str(century)+str(i-1)+".html'>last</a> &nbsp;"+"<a href='"+str(century)+str(i+1)+".html'>next</a>\n"+"<br />")
        htmlOut.write("<a href='"+str(i-1)+".html'>last</a> &nbsp;"+"<a href='"+str(i+1)+".html'>next</a>\n"+"<br />")
        
        htmlOut.write(centroid)
        
        centroidPPN=str(clusterCentroidsPerCentury[century][i])#str(clusters[i][0])
        csvPPNOut=open("./web/data/"+centroidPPN+".csv","w")
        csvPPNOut.write("id,value\n")
        rootPPNNode="all"
        csvPPNOut.write(rootPPNNode+","+"\n")
        csvPPNOut.write(rootPPNNode+"."+centroidPPN+",\n")
        ppnCount=0
    
        for ppn in clusters[i]:
            htmlOut.write("<img width='170' src='"+imgDir+ppn+".jpg' alt='"+ppn+"'/>\n")
            #csvOut.write(rootNode+str(century)+"."+str(clusterCentroidsPerCentury[century][i])+"."+ppn+",\n")
            if ppnCount<limitClusterCentroidsPerCentury*centuryLimitFactor:
                ppnCount=ppnCount+1
                csvCenturyOut.write(rootCenturyNode+"."+str(clusterCentroidsPerCentury[century][i])+"."+ppn+",\n")
            else:
                csvCenturyOut.write(rootCenturyNode+"."+str(clusterCentroidsPerCentury[century][i])+".more,\n")
                break
            
            csvPPNOut.write(rootPPNNode+"."+centroidPPN+"."+ppn+",\n")
        csvPPNOut.close()
        htmlOut.write(htmlTail)
        htmlOut.close()
    
    csvCenturyOut.close()
    print("\tLargest cluster for century %i is %i with %i elements."%(century,largestCluster,largestClusterSize))
    print("\t\tNumber of clusters: %i"%noClustersInCentury)
    print("\t\tMean cluster size: %s"%str(np.mean(clusterSizes)))
    print("\t\tCluster size standard deviation: %s"%str(np.std(clusterSizes)))
    print("\t\tMin. cluster size: %s"%str(np.amin(clusterSizes)))
    print("\t\tMax. cluster size: %s"%str(np.amax(clusterSizes)))
csvOut.close()
printLog("Done.")

# %% [markdown]
# ### A Visual Timeline of Publications
# plotting of the "centroids"

# %%
imgDir="../web/thumbnails/"
htmlHead="<html><head></head><body bgcolor='#000000'>"
htmlTail="</body></html>"
centroidPath="html/_centroids.html"

printLog("Saving centroid overview HTML page at: "+centroidPath)
htmlOut=open(centroidPath,"w")
htmlOut.write(htmlHead)
for century in clustersPerCentury:
    htmlOut.write("<h1 style='color:white;'>"+str(century)+"</h1>\n")
    for centroid in clusterCentroidsPerCentury[century]:
        htmlOut.write("<img width='170' src='"+imgDir+clusterCentroidsPerCentury[century][centroid]+".jpg' />\n")
htmlOut.write(htmlTail)
htmlOut.close()
printLog("Done.")

# %% [markdown]
# we can also extend the idea and create a graph of the data
# to base a nice visualization of the clusters...

# %%
imgDir="./web/thumbnails/"
printLog("Creating overview graph...")
G=nx.Graph()

lastCentury="7"
for century in clustersPerCentury: 
#for century in [7,10,11,12,13,14,15,16]:#range(12,15):
    strCentury=str(century)
    G.add_node(strCentury)
    G.node[strCentury]['name'] = strCentury
    G.node[strCentury]['type'] = "century"
    
    for centroid in clusterCentroidsPerCentury[century]:
        ppn=str(clusterCentroidsPerCentury[century][centroid])
        imagePath=imgDir.replace("file://","")+ppn+".jpg"
        G.add_node(ppn)
        G.node[ppn]['name'] = ppn
        if os.path.isfile(imagePath):
            G.node[ppn]['name'] = ppn
            G.node[ppn]['imagePath'] = ppn
        else:
            G.node[ppn]['name'] = ppn
            G.node[ppn]['imagePath'] = "none"
        G.node[ppn]['title'] = ppnLookup[ppn]['title']
        G.node[ppn]['creator'] = ppnLookup[ppn]['creator']
        if ppnLookup[ppn]['spatialClusterName']:
            G.node[ppn]['location'] = ppnLookup[ppn]['spatialClusterName']
        G.node[ppn]['locationRaw'] =ppnLookup[ppn]['spatialRaw']
        
        G.node[ppn]['mediatype'] =ppnLookup[ppn]['mediatype']
        G.node[ppn]['subject'] =ppnLookup[ppn]['subject']
        G.node[ppn]['source'] =ppnLookup[ppn]['source']
        G.node[ppn]['publisher'] =ppnLookup[ppn]['publisher']
        G.node[ppn]['alternative'] =ppnLookup[ppn]['alternative']
            
        G.node[ppn]["century"]=century
        G.node[ppn]['dateClean'] =ppnLookup[ppn]['dateClean']
        G.node[ppn]["cluster"]=str(centroid)
        G.node[ppn]['lat']=ppnLookup[ppn]['lat']
        G.node[ppn]['lng']=ppnLookup[ppn]['lng']
        G.node[ppn]['type'] = "image"
        G.node[ppn]['textCluster'] =ppnLookup[ppn]['textCluster']
        G.node[ppn]['creatorCluster'] =ppnLookup[ppn]['creatorCluster']
        
        G.add_edge(strCentury,ppn)
    G.add_edge(strCentury,lastCentury)
    lastCentury=strCentury
    
nx.write_gml(G,"graphs/century.gml")
d = json_graph.node_link_data(G)
jsonPath='./web/data/century.json'
#jsonPath='./force/century_test.json'
saveDir="./web/force/"
if not os.path.exists(saveDir):
        os.makedirs(saveDir)
        
json.dump(d, open(jsonPath,'w'))
printLog("Done (see %s)."%jsonPath)

# %%
printLog("Creating cluster graph output...")
imgDir="./web/thumbnails/"

saveDir="./web/data/clusters/"
if not os.path.exists(saveDir):
        os.makedirs(saveDir)

for century in clustersPerCentury:
    printLog("Processing century "+str(century))
    saveDir="./web/data/clusters/"+str(century)+"/"
    if not os.path.exists(saveDir):
        os.makedirs(saveDir)

    clusters=dict()
    for i,val in enumerate(clustersPerCentury[century]):
        if val not in clusters:
            clusters[val]=[]
        clusters[val].append(readPpnPerCentury[century][i])

    for i in clusters:
        G=nx.Graph()
        # the cluster's centroid
        centroid=str(clusterCentroidsPerCentury[century][i])
        G.add_node(centroid)
        G.node[centroid]['type'] = "centroid"
        
        for ppn in clusters[i]:
            imagePath=imgDir.replace("file://","")+ppn+".jpg"
            #dateClean=str(df4[df4.PPN==ppn].iloc[-1]['dateClean'])
            dateClean=ppnLookup[ppn]["dateClean"]
            G.add_node(dateClean)
            G.node[dateClean]['name'] = dateClean
            G.node[dateClean]['type'] = "dateClean"
            G.add_edge(centroid,dateClean)
            
            G.add_node(ppn)
            G.node[ppn]['name'] = ppn
            if os.path.isfile(imagePath):
                G.node[ppn]['name'] = ppn
                G.node[ppn]['imagePath'] = ppn
            else:
                G.node[ppn]['name'] = ppn
                G.node[ppn]['imagePath'] = "none"
            #G.node[ppn]['title'] = df4[df4.PPN==ppn].iloc[-1]['title']
            #G.node[ppn]['creator'] = str(df4[df4.PPN==ppn].iloc[-1]['creator'])
            #G.node[ppn]['location'] = df4[df4.PPN==ppn].iloc[-1]['spatialClusterName']
            G.node[ppn]['title'] = ppnLookup[ppn]["title"]
            G.node[ppn]['creator'] = ppnLookup[ppn]["creator"]
            if ppnLookup[ppn]["spatialClusterName"]:
                G.node[ppn]['location'] = ppnLookup[ppn]["spatialClusterName"]
            else:
                G.node[ppn]['location']="none"
            G.node[ppn]['locationRaw'] =ppnLookup[ppn]['spatialRaw']
            
            G.node[ppn]['mediatype'] =ppnLookup[ppn]['mediatype']
            G.node[ppn]['subject'] =ppnLookup[ppn]['subject']
            G.node[ppn]['source'] =ppnLookup[ppn]['source']
            G.node[ppn]['publisher'] =ppnLookup[ppn]['publisher']
            G.node[ppn]['alternative'] =ppnLookup[ppn]['alternative']
            G.node[ppn]['dateClean'] =ppnLookup[ppn]['dateClean']
            G.node[ppn]['lat']=ppnLookup[ppn]['lat']
            G.node[ppn]['lng']=ppnLookup[ppn]['lng']
            
            if ppn==centroid:
                G.node[centroid]['type'] = "centroid"
            else:
                G.node[ppn]['type'] = "image"
            
            G.add_edge(dateClean,ppn)
            
        nx.write_gml(G,saveDir+str(i)+".gml")
        d = json_graph.node_link_data(G)
        jsonPath='./web/data/clusters/'+str(century)+'/'+str(i)+'.json'
        json.dump(d, open(jsonPath,'w'))
printLog("Done.")

# %% [markdown]
# ## Geospatial Extravaganza

# %%
# points are latitude, longitude
# Latitudes range from -90 to 90.
# Longitudes range from -180 to 180
newport_ri = (41.49008, -71.312796)
cleveland_oh = (41.499498, -81.695391)
test=(-95,-161)
x=vincenty(newport_ri, test)
print(x.kilometers)

# %%
index=0
ppnPosition=[]
ppnPositionLabels=[]
ppnPositionSpatialClean=[]

printLog("Extracting latitude and longitude...")

for row in df4.iterrows():
    index=index+1
    if index%10000==0:
        printLog("Processed %i documents."%index)
    ppn=str(row[1]["PPN"])
    try:
        lat=float(row[1]["latitude"])
        lng=float(row[1]["longitude"])
        spatialClean=row[1]["spatialClean"]
        if math.isnan(lat) and math.isnan(lng):
            pass
        else:
            ppnPositionLabels.append(ppn)
            ppnPositionSpatialClean.append(spatialClean)
            ppnPosition.append((lat,lng))
    except TypeError:
        #print(row[1]["latitude"])
        pass
    
printLog("Found %i PPNs with coordinates." %len(ppnPositionLabels))

# %%
plt.title('Distribution of Geo-Spatial Coordinates')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.scatter(*zip(*ppnPosition),alpha=0.1)
if saveFiguresAsPDF:
    plt.savefig('./figures/sample.pdf')

# %% [markdown]
# * Latitudes range from -90 to 90. -> x-Achse sollte 180 breit sein, Mitte ist 90
# * Longitudes range from -180 to 180 -> y-Achse sollte 360 breit sein, Mitte ist 180

# %%
feats=ppnPosition

# define the number of clusters to be found
true_k=30
printLog("Clustering of %i elements started with %i as cluster target size."%(len(feats),true_k))
# initialize the k-means algorithm
#km = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
# we will rely on the mini batch k-means algorithm due to performance consideration otherwise your computer might crash...
km = MiniBatchKMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)

# apply the algorithm on the data
km.fit(feats)
printLog("Clustering finished.")
km.labels_

# %% [markdown]
# bounding boxes aus http://boundingbox.klokantech.com/

# %% [markdown]
# Visualization with GeoJSON (http://geojson.org/) https://pypi.python.org/pypi/geojson and OpenLayers  http://openlayers.org/en/latest/doc/ http://openlayers.org/en/latest/apidoc/

# %%
regions=["Europe","Africa","Asia","Australia","SouthAmerica","NorthAmerica"]
regionBoundingBox=dict()
#westlimit=-22.5; southlimit=33.6; eastlimit=58.4; northlimit=82.9
regionBoundingBox["Europe"]=[33.6,82.9,-22.5,58.4]
#africa westlimit=-22.9; southlimit=-63.7; eastlimit=58.0; northlimit=37.2
regionBoundingBox["Africa"]=[-63.7,37.2,-22.9,58.0]
#asia westlimit=29.5; southlimit=-11.4; eastlimit=-168.4; northlimit=81.2
regionBoundingBox["Asia"]=[-11.4,81.2,-168.4,29.5]
#australia westlimit=112.5; southlimit=-50.4; eastlimit=-162.9; northlimit=-10.0
regionBoundingBox["Australia"]=[-50.4,-10.0,-162.9,112.5]
#south america westlimit=-119.5; southlimit=-57.0; eastlimit=-29.9; northlimit=28.1
regionBoundingBox["SouthAmerica"]=[-57.0,28.1,-119.5,-29.9]
#north america westlimit=-169.1; southlimit=23.7; eastlimit=-20.0; northlimit=71.4
regionBoundingBox["NorthAmerica"]=[23.7,71.4,-169.1,-20.0]


# man muss checken in welchen intervallen die kontinente liegen, insb. bei 2 und 3
def getRegion(lat,lng):
    for region in regions:
        if region in regionBoundingBox:
            if regionBoundingBox[region][0] <= lat <= regionBoundingBox[region][1]:
                if regionBoundingBox[region][2] <= lng <= regionBoundingBox[region][3]:
                    return region

    return "other"

#print getRegion(51,10)

# %%
# combine all arrays and check if there is more than one location associated with a PPN
# ppnPosition is (lat,lng)
printLog("Creating GeoJSON data...")
multipleCitiesPPN=pickleDecompress("./picklez/multipleSpatialNamesPerPPN.picklez")

baseDir="./web/data/layers/"
fileName=baseDir+"test.json"
locationFeatures=dict()
locationFeaturesGlobal=[]

spots=zip(ppnPositionLabels, ppnPositionSpatialClean,ppnPosition)

for spot in spots:
    ppn=spot[0]
    leadingLoc=spot[1]
    latLng=spot[2]
    # GeoJSON points are in longitude , latitude but our storage is lat/lng
    my_point = gj.Point((latLng[1], latLng[0]))

    region=getRegion(latLng[0],latLng[1])
    if region not in locationFeatures:
        locationFeatures[region]=[]
        print("Adding "+region)
    else:
        locationFeatures[region].append(gj.Feature(geometry=my_point, properties={"title": leadingLoc+" "+ppn, "ppn":ppn}))
    
    locationFeaturesGlobal.append(gj.Feature(geometry=my_point, properties={"title": leadingLoc+" "+ppn, "ppn":ppn}))
    #print ppn
    if ppn in multipleCitiesPPN:
        array=multipleCitiesPPN[ppn]
        #if there are alternative locations for this PPN
        if len(array)>1:
            #print leadingLoc+" "+ppn
            #print "\t"+"; ".join(array).encode("utf-8")
            pass

for region in locationFeatures:
    geoJSON_collection=gj.FeatureCollection(locationFeatures[region])
    dump = gj.dumps(geoJSON_collection, sort_keys=True)

    jsonFile = open(baseDir+region.lower()+".json", "w")
    jsonFile.write(dump)
    jsonFile.close()
    

geoJSON_collection=gj.FeatureCollection(locationFeaturesGlobal)
dump = gj.dumps(geoJSON_collection, sort_keys=True)

globalJSONPath=baseDir+"global.json"
jsonFile = open(globalJSONPath, "w")
jsonFile.write(dump)
jsonFile.close()
printLog("Serialized %i metadata records.\n\tSaved global JSON document at %s." %(len(locationFeaturesGlobal),globalJSONPath))

printLog("Done.")

# %%
#print spots.index("PPN766441857")
#print(spots[10])
#print(getRegion(spots[10][2][0],spots[10][2][1]))

# %%
# we will create an inverted mapping from alternative location names to "leading" location names
# the resulting dicts "main" key will be the leading character of the alternative location name 
# within this map will be a mapping to the "leading" location name, e.g., 'Corfu' would be mapped to 'Korfu'
# lastLetter=r[0].lower()
osmNames=pickleDecompress('./picklez/osm_names.picklez')
osmAlternativesSorted=dict()
for leadLoc in osmNames:
    #print leadLoc
    for v in osmNames[leadLoc].values():
        leadingLetter=v[0].lower()
        if not leadingLetter in osmAlternativesSorted:
            osmAlternativesSorted[leadingLetter]=dict()
        else:
            osmAlternativesSorted[leadingLetter][v]=leadLoc

# %%
# osmNames(key): alle alternativen titel in der Form names[loc][u'name']:
# u'Ems': {u'name:nl': u'Eems', u'name': u'Ems', u'name:de': u'Ems', u'name:la': u'Amisia'...
# latLng(key)[lat|lng]: latitude/longitude pro key

# %% [markdown]
# # Ideen
#
# * Timeline und Grafisches Aussehen, x-Achse: Zeit, y-Achse. Farbe? Brightness? Entropy? Abweichung vom Referenzbild (Distanz zum QBE)? https://www.slideshare.net/formalist/how-and-why-study-big-cultural-data-v2-15552598 #43
# * Dominante Farbe bestimmen, als 3D-Punkt nehmen und schauen, ob es mit etwas korreliert?
# * Stabi-URL:

# %%
#g=df4.groupby("publisher")
#g.describe()

# %%
#g.count().plot(legend=False)

# %% [markdown]
# # Service Functions
# to avoid problems with JSON access you should load the web pages from your own HTTP server

# %%
if True:#launchHTTPServer:
    # the resulting HTTP service will listen on port 8000 and open the main page in the browser
    import http_server
    http_server.load_url('web/webapps/index.html')
